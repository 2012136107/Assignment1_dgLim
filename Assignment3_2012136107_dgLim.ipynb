# %% [markdown]
# ### 문제 1
#
# - L = [1,2,3,4,5]일 떄 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.

# %% [markdown]
#  - 1)
#     - L[1:3] = [100]
#     - print(L)

# %%
L = [1,2,3,4,5]

L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# #### [설명] 리스트에 원소에 대한 슬라이스 치환
#
# - ##### 서로 다른 크기에 대한 슬라이스 치환
#
# L[1:3], (1인덱스 포함, 3인덱스 미포함) 즉, 리스트의 2, 3번째에 해당하는 원소의 값을 100으로 바꾼다.
#  따라서, 리스트의 2, 3번째의 원소 값, 2, 3을 100으로 치환
#
# 수행 결과로는 L = [1, 100, 100, 4, 5]이 된다.

# %% [markdown]
# - 2)
#   - L[1:3] = [(100)]
#   - print(L)

# %%
L = [1,2,3,4,5]

L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# #### [설명]
#
# 리스트의 원소로 튜플을 가질 수 있다.
#
# - #### 서로 다른 크기에 대한 슬라이딩
#
# L = [1, 2, 3, 4, 5] 일 때,
#
# 예를 들면, L[1:2] = [(100, 200, 300)]을 수행시키면,
#
#   L = [1, (100, 300, 400), 3, 4, 5]가 될 것이다.
#
# L[1:3] = [(100)]을 수행시키면, 1:3에 해당하는 자리에 원소로 튜플(100)이 대입된다.
#
#   L = [1, 100, 4, 5]이 된다.

# %% [markdown]
# - 3)
#   - L[1:3] = 100
#   - print(L)

# %%
L = [1, 2, 3, 4, 5]

L[1:3] = 100

print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-cb5ad51a6bf9> in <module>()
#       1 L = [1, 2, 3, 4, 5]
#       2
# ----> 3 L[1:3] = 100
#       4
#       5 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# #### [설명]
#
# 리스트는 인덱스별로 꺼내서 할당해야 한다.
#
# 예를 들면, L = [1, 2, 3, 4, 5]일 때,
#
# L[1] = 100
#     -> [1, 100, 3, 4, 5]
#
# L[1:3] = 100, 200
#     -> [1, 100, 3, 4, 5]
#
# 하지만, 인덱스 별로 꺼내서 할당하지 않고, 한 번에 할당하려고 하는
#
# L[1:3] = 100
#
# 를 수행하게 되면 TypeError : can only assign an iterable 발생한다.
#
# 따라서, 결과를 얻기 위해선 각 인덱스 별로 꺼내서 할당하게끔
#
# L[1:3] = 100, 100 -> [1, 100, 100, 4, 5]
#
# 으로 해야한다.

# %% [markdown]
# - 4)
#   - L[1:3] = (100)
#   - print(L)

# %%
L = [1, 2, 3, 4, 5]

L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-85f945e96748> in <module>()
#       1 L = [1, 2, 3, 4, 5]
#       2
# ----> 3 L[1:3] = (100)
#       4 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# #### [설명]
#
# 마찬가지로 각 인덱스 별로 할당해야 하지만, 크기가 다르므로 TypeError: can only assign an iterable 에러 발생.
#
# 따라서, 리스트 L의 [1:3] 원소에 100의 값을 넣기 위해선 위 문제에서 다룬 것 처럼 L[1:3] = 100, 100 혹은, L[1:3] = [100, 100]을 하거나, L[1:3] = (100, 100)을 하면 된다.

# %% [markdown]
# - 5)
#   - L[1:3] = (100, 101, 102)
#   - print(L)

# %%
L = [1, 2, 3, 4, 5]

L[1:3] = (100, 101, 102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# #### [설명]
#
#  서로 다른 크기에 대한 슬라이싱
#
#  1에서 2의 인덱스에 해당하는 값 2, 3자리에 100, 101, 102가 와서 총 원소의 개수가 늘어난다. 총 원소는 6개

# %% [markdown]
# - 6)
#   - L[1:3] = [100, 101, 102]
#   - print(L)

# %%
L = [1, 2, 3, 4, 5]

L[1:3] = [100, 101, 102]
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# #### [설명]
#
#  서로 다른 크기에 대한 슬라이싱에, 리스트로 값을 집어넣을 때,
#
#  1에서 2의 인덱스에 해당하는 값 2, 3의 위치에 리스트 [100, 101, 102]값으로 치환된다. 총 원소는 6개

# %% [markdown]
# - 7)
#   - L[1:3] = [(100, 101, 102)]
#   - print(L)

# %%
L = [1,2,3,4,5]

L[1:3] = [(100, 101, 102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# #### [설명]
#
#  서로 다른 크기에 대한 슬라이싱에, 원소로 튜플을 갖는 코드
#
#  1에서 2의 인덱스에 해당하는 값 2, 3이 튜플 (100, 101, 102)으로 바뀐다. 총 원소는 4개

# %% [markdown]
# - 8)
#   - L[1:3] = [[100, 101, 102]]
#   - print(L)

# %%
L = [1, 2, 3, 4, 5]

L[1:3] = [[100, 101, 102]]
print(L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# #### [설명]
#
# 리스트의 원소로 리스트가 올 수 있다. 그리고 서로 다른 크기에 대한 슬라이싱이다.
#
# 1에서 2의 인덱스에 해당하는 값 2, 3이 리스트 [100, 101, 102]로 바뀐다.
# 총 원소의 개수는 4개

# %% [markdown]
# ### 문제 2
#
# - 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
#   - 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#   - 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'

str1 = S.split()     # 리스트str1에 문자열 S를 공백을 기준으로 쪼갠 단어들을 원소들로 갖는다.
str1 = str1[::-1]    # 리스트str1의 원소들을 역순으로 대입
S = " ".join(str1)   # " "즉, 공백을 띄우고 str1의 원소들을 합쳐 문자열을 만든 S

print(S)

print()

str2 = S.split()     # 문자열 S을 다시 공백을 기준으로 쪼개 리스트str2에 대입
S = "".join(str2)    # "" 즉, 공백 없이 str2의 원소들을 합쳐 문자열 S를 만듦

print(S)
# Out:
# Python and World Hello
#
# PythonandWorldHello

# %% [markdown]
# #### [설명]
#
# 문자열 메소드 split()는 문자열을 공백을 기준으로 쪼갠 원소들을 가지는 리스트를 만드는 것이고, 문자열 메소드 join()은 입력받은 리스트의 원소들을 합치는 메소드이다. 이 때, " ".join(입력 리스트)는 각 원소 사이에 공백을 가지고 문자열로 합치는 것

# %% [markdown]
# ### 문제 3
#
# - 다음 코드를 보고 물음에 답하시오.
#
#   a = [1, 2, 3]
#
#   b = a * 3
#
#   c = [a] * 3
#
#   print(b)
#
#   print(c)
#
#   - 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#
#   a[0]=0
#
#   - 2) b와 c 객체의 차이는 무엇인가?

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3

print(b)
print(c)

print()

a[0] = 0
print(b)
print(c)


print(id(a))
print(id(b))
print(id(c[1]))
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
#
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]
# 2029965065032
# 2029965064904
# 2029965065032

# %% [markdown]
# #### [설명]
#
# - b 객체는, 리스트 원소의 반복을 표현하는 방법으로 리스트 * 연산(곱하기)를 사용할 수 있다.
#   - 즉, 리스트 * 반복 하고 싶은 횟수
#
#
# - c 객체는, 리스트 자체를 반복 표현하는 방법으로 [리스트] * 연산(곱하기)를 사용하여 표현한다.
#   - 즉, [리스트] * 반복 하고 싶은 횟수
#
# a[0] = 0 수행 후
#
# b는 a의 원소 값만을 이용하여 새로운 객체를 만든 것
# c는 원소 중 일부가 리스트 a를 참조하는 새로운 객체를 만든 것. (단, 이 때, 각 원소는 a를 참조)

# %% [markdown]
# ### 문제 4
#
# - 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#
#
#       s = '  first star   :   second star   :    third star  '
#       l = ['first star', 'second star', 'third star']
#
#
#   - 1) for ~ in 문을 이용한 코드를 작성하시오.
#   - 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '
str1 = s.split(':')      # 문자열을 ':'를 기준으로 쪼개 str1 리스트의 원소로 갖는다.  

                         # 1) for ~ in문을 이용한 코드
for x in range(len(str1)):
    l[x] = str1[x].strip()

print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# #### [설명]
#
#  우선, 문자열을 :을 기준으로 쪼개 원소로 갖는 리스트 str1을 만든다.
#
#  l은 최종적으로 ':', 공백이 제거된 원소들을 갖는 리스트이므로, 선언과 동시에 길이를 정해준다.
#
#  for~in문은 범위(range(len(str1)), 즉 3)이며,
#  리스트 l의 각 인덱스에 맞게 ':'을 기준으로 쪼갠 문자열 str1의 원소들에서 양 공백을 제거한(strip()) 원소를 갖는다.

# %%
# 2) 리스트 내포(list comprehension)을 이용한 코드

s = '  first star   :   second star   :    third star  '
str1 = s.split(':')      # 문자열을 ':'를 기준으로 쪼개 str1 리스트의 원소로 갖는다.  

l = [str1[x].strip() for x in range(len(str1))]

print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# #### [설명]
#
# 리스트 내포(list comprehension)를 이용한 코드는
#
# [표현식 for ~ in]으로 표현할 수 있다.
#
# 따라서 l = [str1[x].strip() for x in range(len(str1))]

# %% [markdown]
# ### 문제 5
#
# - 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
#
#   - 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#         >>> addall([1])
#         1
#         >>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
#         45

# %%
# 1) for-in
def addall(list_1):
    sum = 0
    for x in range(len(list_1)):
        sum = sum + list_1[x]
    return print(sum)

addall([1])
addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 1
# 45

# %%
# 1) 리스트 내포
def addall(list_1):
    return print(sum([list_1[x] for x in range(len(list_1))]))

addall([1])
addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 1
# 45

# %% [markdown]
#   - 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#         >>> addallodd([1])
#         1
#         >>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
#         25

# %%
# 1) for-in
def addallodd(list_1):
    sum = 0
    for x in range(len(list_1)):
        if(list_1[x]%2 == 1):
            sum = sum + list_1[x]
    return print(sum)

addallodd([1])
addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 1
# 25

# %%
# 1) 리스트 내포
def addall(list_1):
    return print(sum([list_1[x] for x in range(len(list_1)) if list_1[x]%2 == 1]))

addallodd([1])
addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 1
# 25

# %% [markdown]
# #### [설명]
#
# 리스트 변수를 인자로 받는 함수 addall, addallodd를 만들 때, 함수문 선언을 하고, 그 내부에 for~in, 리스트 내포 두 가지 방법으로 제시하는 문제이다.
#  우선, for~in 방법으로 문제를 해결할 때는 내장함수 sum()을 사용하지 않고, 리스트의 각 원소의 값의 합을 저장할 sum = 0을 선언하여 해결한다.
#  sum = sum + list[x]
#   addallodd 함수를 for~in 방법으로 해결 할 때는 조건만 하나 달아주면 된다. 홀수 이면 더하도록 if(list[x]%2 == 1)일 때만, 더하면 된다.
#  둘째로, 리스트 내포 방식으로 문제를 해결하기 위해서는 내장함수 sum()을 이용해야 하는데, 리스트 내포 방식의 출력은 리스트이므로 sum()을 이용해서 리스트 결과값의 각 원소의 합을 출력하도록 한다.
#  리스트 내포에서 조건문을 쓰는 방법은 for~in과 달리 위 문제와 같이 쓰면 된다.

# %% [markdown]
# ### 문제 6
#
# - 다음 코드를 보고 물음에 답하시오.
#
#     L1 = [1, 2, 3]
#
#     L2 = [4, 5, 6]
#
#     d = {'low':L1, 'high':L2}
#
#     e = d
#
#     f = d.copy()
#
#     print(d)
#
#     print(e)
#
#     print(f)
#
#     print()
#
#     d['low'] = [10, 20, 30]
#
#     d['high'][1] = 500
#
#     print(d)
#
#     print(e)
#
#     print(f)
#
#
# - 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
# - 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
#
#     {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()

print(d)
print(e)
print(f)
print()

d['low'] = [10, 20, 30]
d['high'][1] = 500

print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
#
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# #### [설명]
#
#  위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 d와 e는 같은 객체를 가리키고 있기 때문이다.
#  따라서,
#
#  d['low'] = [10, 20, 30]
#
#  d['high'][1]
#
#  는 새로운 객체를 만드는 것이 아니라 참조하고 있던 객체의 원소 값을 변경하기 때문에, 같은 객체를 가리키고 있는 d와 e는 같은 결과를 출력한다.
#
#  f는 d객체에 내장함수 copy()를 이용한 얕은 복사(Shallow Copy)했으므로, 객체가 가진 멤버의 값들을 새로운 객체로 복사하는데, 객체가 참조 타입의 멤버를 가지고 있으면 참조 값만 복사되기 때문이다.

# %% [markdown]
# ### 문제 7
#
# - 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#   - [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#
#
# -  1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
# - 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
import operator

d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}

a = [a for a in d.items()]
a.sort()                             # 키의 알파벳 오름차순으로 정렬
print(a)
print()

i.reverse()                          # 키의 알파벳 내림차순으로 정렬
print(a)
print()
                                     # 값의 오름차순으로 정렬
print(sorted(d.items(), key=operator.itemgetter(1)))
print()
                                     # 값의 내림차순으로 정렬
print(sorted(d.items(), key=operator.itemgetter(0)))
print()
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
#
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
#
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
#
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]

# %% [markdown]
# #### [설명]
#
# i = [i for i in d.items()]를 이용하여 사전 d의 items들을 리스트 내 튜플 원소 형태로 객체 i를 만든다.
#
#  그 뒤에 i.sort()로 key의 알파벳 오름차순을 기준으로 정렬한다.
#   아무런 조건없이 sort() 함수를 슨다면 key를 기준으로 한다.
#
#  그리고, i.reverse()를 이용하여 key의 알파벳 오름차순으로 정렬된 리스트를 역순으로 즉, 알파벳 내림차순을 기준으로 정렬한다.
#
#   value를 기준으로 정렬하기 위해서 나는 sorted 메소드를 사용했는데,
#   sorted(d.items(), key=operator.itemgetter(1), 1의 값을 주면 오름차순으로 정렬
#   0의 값을 주면 내림차순으로 정렬한다.
#
#   이 메소드 처럼 사용하기 위해서는 operator 모듈을 import 해야한다.

# %% [markdown]
# ### [ACM-ICPC 문제 1152]
# - 단어의 개수
#
#   - 영어 대소문자와 띄워쓰기만으로 이루어진 문장이 주어진다. 이 문장에는 몇 개의 단어가 있을까? 이를 구하는 프로그램을 작성하시오. 단, 단어는 띄워쓰기 하나로 구분된다고 생각한다.

# %%
s = input()
print(len(s.split()))
# Out:
# The Curious Case of Benjamin Button
# 6

# %% [markdown]
# #### [설명]
# 첫 문장에 문자열을 입력받고, 입력받은 문자열을 공백을 기준으로 쪼갠다.

# %% [markdown]
# <img src="img/1152.png" height = 50%>

# %% [markdown]
# <img src="1152.png">

# %% [markdown]
# #### [Incremental Project]
#
# - 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
#
#
#   - 요구사항 1. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#
#     - 예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] -->['world', 'hello', 'python', 'world']
#
#     - 모든 punctuation을 확인하는 방법은 아래와 같다.
#
#         import string
#
#         print(string.punctuation)
#
#
#   - 요구사항 2. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#
#     - 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '지향']
#
#
#   - 요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#
#     - 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#
#
#  - 요구사항 4. 다음 3개의 사이트에 대한 결과를 출력하시오.
#
# http://www.naver.com
#
# http://www.daum.net
#
# http://www.nytimes.com

# %%
import string

from urllib import request 
 
url = 'http://www.naver.com'

f = request.urlopen(url)
source_bytes = f.read()
source = source_bytes.decode('utf-8')

source.strip()                                  #양 쪽 끝에 있는 공백을 없앤다.
a = 0
b = 0
count = 0                                       #HTML 구문, 코드를 제외한 문자의 개수
t1 = 0
t2 = 0
c = []

i = 0
# javaScript 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<script', t2)
        t2 = source.find('</script>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1
    
i = 0
# CSS 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<style', t2)
        t2 = source.find('</style>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1

while(a != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 
                                                # < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
    a = source.find('<', b) 
    b = source.find('>', a) 
    a1 = source.find('<', b)

    if((a1 > b) and (a1 != a) ):                # > 이 사이에 있는 것이 문자열이라는 조건 <
        count = count + len(source[(b+1):a1].split())        # 그 사이에 있는 것이 문자열인데 그 안에 단어가 몇개 있는지를 공백 기준 쪼갠다.
        if(len(source[(b+1):a1].split()) > 0):
            c = c + source[(b+1):a1].split()
            
c = ' '.join(c)        # 리스트는 구두문자를 제거하기 위한 translate를 사용할 수 없으므로 문자열로 만든다. 이 때, 각 원소의
                       # 구분은 공백문자로 한다. 이후에 공백문자를 기준으로 다시 리스트를 만들 것이다.
translator = str.maketrans('', '', string.punctuation)
c = c.translate(translator)
c = c.split()
k = 0
result = []

#리스트 내에 구두문자를 제거한 단어들을 삽입한다.
while(k < len(c)):
    result.append((c[k],c.count(c[k])))
    k = k + 1

    
#중복 문자 삭제
result = set(result)

#리스트로의 형변환
result = list(result)

# 사전화
k = 0
list_key = []
list_value = []

while(k < len(result)):
    list_key.append(result[k][0])
    list_value.append(result[k][1])
    k = k + 1
 
#key, value(반복횟수)를 리스트로 각각 저장했었기 때문에, 리스트와 리스트 간
#mapping을 위해 zip()사용.

t = zip(list_key, list_value)

#zip 후, 사전으로 형변환
t = dict(t)

print(count) #중복을 제외한 단어의 개수
print()
print(t)
# Out:
# 1005
#
# ...

# %% [markdown]
# #### [설명]
#
# -  우선, 전체적인 url에서 '<', '>'을 구분하여 단어를 추리기 전에, java Script와 CSS로 이루어진 태그를 먼저 처리하고 나서 해야 원하는 결과 값을 얻을 수 있다고 판단했다.
#
# -  따라서, < script>가 시작하는 인덱스에서 < /script>로 끝나는 java Script의 태그와 그 안에 있는 내용을 먼저 제거했다. 제거 방법은 슬라이싱을 이용했는데,
#  t1은 자바 스크립트가 시작하는 인덱스이며, t2는 자바 스크립트가 끝나는 인덱스로 그 사이의 내용을 없애기 위해 [:t1] + [t2:]의 범위를 취했다.
#
# -  마찬가지로, CSS 태그인 < style, < /style>또한 마찬가지로 제거했다.
#
# -  그렇게 나온 source를 가지고 지난 시간에 했던 html 태그를 제외한 문자들을 구하는 내용을 넣었다.
#
# -  이렇게 나온 단어들에서 구두문자를 제거해야한다.
#
# -  translate(None, string.punctuation)은 구두점이 스트링에 포함되어 있으면 모두 제거하라는 의미이나, 이 방법은 python 2.* version에서 사용하던 방법이었고,
#  python3에서는 str.maketrans('', '', string.punctuation), translate(c)를 이용하는 방법으로 사용해야만 했다.
#
# - 이 때, 리스트를 받아오지 못하므로 문자열로 전환하기 위해 join을 이용했다.
#
# - 그렇게 구두문자를 제거한 c는, 사전에 넣고 key로 단어, value로 그 단어의 중복 횟수를 넣을 것이지만, 바로 사전에 입력하면 중복된 내용이 기입되므로, 순서상 그 단어의 중복횟수를 저장하고 나서 set을 이용해 중복을 제거해야한다. 따라서, key, value에 해당하는 리스트를 저장하고, 중복을 제거하고 나서 따로따로 key, value를 만들어 사전으로 합치도록 zip(), dict()을 이용하였다.

# %%
import string

from urllib import request 
 
url = 'http://www.daum.net'

f = request.urlopen(url)
source_bytes = f.read()
source = source_bytes.decode('utf-8')

source.strip()                                  #양 쪽 끝에 있는 공백을 없앤다.
a = 0
b = 0
count = 0                                       #HTML 구문, 코드를 제외한 문자의 개수
t1 = 0
t2 = 0
c = []

i = 0
# javaScript 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<script', t2)
        t2 = source.find('</script>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1
    
i = 0
# CSS 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<style', t2)
        t2 = source.find('</style>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1

while(a != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 
                                                # < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
    a = source.find('<', b) 
    b = source.find('>', a) 
    a1 = source.find('<', b)

    if((a1 > b) and (a1 != a) ):                # > 이 사이에 있는 것이 문자열이라는 조건 <
        count = count + len(source[(b+1):a1].split())        # 그 사이에 있는 것이 문자열인데 그 안에 단어가 몇개 있는지를 공백 기준 쪼갠다.
        if(len(source[(b+1):a1].split()) > 0):
            c = c + source[(b+1):a1].split()
            
c = ' '.join(c)        # 리스트는 구두문자를 제거하기 위한 translate를 사용할 수 없으므로 문자열로 만든다. 이 때, 각 원소의
                       # 구분은 공백문자로 한다. 이후에 공백문자를 기준으로 다시 리스트를 만들 것이다.
translator = str.maketrans('', '', string.punctuation)
c = c.translate(translator)
c = c.split()
k = 0
result = []

#리스트 내에 구두문자를 제거한 단어들을 삽입한다.
while(k < len(c)):
    result.append((c[k],c.count(c[k])))
    k = k + 1

    
#중복 문자 삭제
result = set(result)

#리스트로의 형변환
result = list(result)

# 사전화
k = 0
list_key = []
list_value = []

while(k < len(result)):
    list_key.append(result[k][0])
    list_value.append(result[k][1])
    k = k + 1
 
#key, value(반복횟수)를 리스트로 각각 저장했었기 때문에, 리스트와 리스트 간
#mapping을 위해 zip()사용.

t = zip(list_key, list_value)

#zip 후, 사전으로 형변환
t = dict(t)

print(count) #중복을 제외한 단어의 개수
print()
print(t)
# Out:
# 1036
#
# ...

# %%
import string

from urllib import request 
 
url = 'http://www.nytimes.com'

f = request.urlopen(url)
source_bytes = f.read()
source = source_bytes.decode('utf-8')

source.strip()                                  #양 쪽 끝에 있는 공백을 없앤다.
a = 0
b = 0
count = 0                                       #HTML 구문, 코드를 제외한 문자의 개수
t1 = 0
t2 = 0
c = []

i = 0
# javaScript 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<script', t2)
        t2 = source.find('</script>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1
    
i = 0
# CSS 태그 없애기
while(i != 2):
    while(t1 != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
        t1 = source.find('<style', t2)
        t2 = source.find('</style>', t1)

        if(t1 != t2):
            source = source[:t1] + source[t2:]

    t1 = 0
    t2 = 0
    i = i + 1

while(a != -1):                                 # a != -1의 조건 기준은 source.find('<', b)에서 b 인덱스 이후로 
                                                # < 문자가 더이상 존재하지 않을 때, a에다가 -1을 리턴해준다.
    a = source.find('<', b) 
    b = source.find('>', a) 
    a1 = source.find('<', b)

    if((a1 > b) and (a1 != a) ):                # > 이 사이에 있는 것이 문자열이라는 조건 <
        count = count + len(source[(b+1):a1].split())        # 그 사이에 있는 것이 문자열인데 그 안에 단어가 몇개 있는지를 공백 기준 쪼갠다.
        if(len(source[(b+1):a1].split()) > 0):
            c = c + source[(b+1):a1].split()
            
c = ' '.join(c)        # 리스트는 구두문자를 제거하기 위한 translate를 사용할 수 없으므로 문자열로 만든다. 이 때, 각 원소의
                       # 구분은 공백문자로 한다. 이후에 공백문자를 기준으로 다시 리스트를 만들 것이다.
translator = str.maketrans('', '', string.punctuation)
c = c.translate(translator)
c = c.split()
k = 0
result = []

#리스트 내에 구두문자를 제거한 단어들을 삽입한다.
while(k < len(c)):
    result.append((c[k],c.count(c[k])))
    k = k + 1

    
#중복 문자 삭제
result = set(result)

#리스트로의 형변환
result = list(result)

# 사전화
k = 0
list_key = []
list_value = []

while(k < len(result)):
    list_key.append(result[k][0])
    list_value.append(result[k][1])
    k = k + 1
 
#key, value(반복횟수)를 리스트로 각각 저장했었기 때문에, 리스트와 리스트 간
#mapping을 위해 zip()사용.

t = zip(list_key, list_value)

#zip 후, 사전으로 형변환
t = dict(t)

print(count) #중복을 제외한 단어의 개수
print()
print(t)
# Out:
# 2952
#
# ...

# %% [markdown]
# #### [소감]
#
#  이 번 과제는 생각보다 리스트와 튜플, 그리고 다양한 내장함수에 대한 이해가 없다면 매우 어려웠을 것이다. 본 과제를 통해 더 잘 이해할 수 있었고, 여러가지의 모듈의 종류와 사용법에 대해 배울 수 있었다.
#  다만, 중간고사 시험이 많이 남아있어서 더 쉽고 빠른 방식의 코딩을 하지 못해서 아쉽다.
