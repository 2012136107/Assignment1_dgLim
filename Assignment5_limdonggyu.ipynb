# %% [markdown]
# ### [1번 문제]
# #### 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# - 클래스와 모듈은 이름 공간을 지원하는 단위라는 점에서 공통점이 있다. 이 두 단위의 차이점은 지원하는 이름 공간 영역인데, 모듈은 파일 단위로 이름을 구성하는 반면, 클래스는 클래스 영역 내에 이름 공간을 구성한다.

# %% [markdown]
# ### [2번 문제]
# #### 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# - 조금 언어학적인 측면에서 분석하면 다형성(Polymorphism)의 'Poly'는 많은(many, much)를 의미하고, 'Morphe'는 형식, 형태를 의미한다. 직관적으로 다양한 형태를 뜻하게 되는데, 컴퓨터 과학에서는 단일한 인터페이스에 다양한 자료 개체를 지원하는 것을 의미한다. 파이썬에서 클래스가 지니는 다형성(Polymorphism)이란 상속 관계 내의 다른 클래스들의 인스턴스들이 같은 멤버 함수 호출에 대해 각각 다르게 반응하도록 하는 기능이다. 연산자 오버로딩도 다형성을 지원하는 중요한 기술이다. 다형성의 장점으로는 작성 코드량을 줄여 프로그래머의 생산성을 높여주며, 다양한 객체에게 유사한 작업을 직관적으로 손쉽게 시행시킬 수 있으며, 가독성을 높여준다는 점 등이 있다.

# %%
#/usr/local/bin/python
# coding: utf-8

class Animal:              #Parent Class
    def cry(self):
        print('this is Animal class')

class Dog(Animal):     #Child Class 1
    def cry(self):
        print('mung!!!')

class Cat(Animal):       #Child Class 2
    def cry(self):
        print('nyang')

class COW(Animal):   #Child Class 3
    def cry(self):
        print('ummmmmm mo')

for each in (Dog(), Cat(), COW()):
    each.cry()
# Out:
# mung!!!
# nyang
# ummmmmm mo

# %% [markdown]
# #### [설명]
#
# 부모 클래스로 Animal 클래스를 만들고, 이를 상속받는 Dog, Cat, COW 클래스를
# 만들었다. 각각이 인자로 상속받을 클래스인 Animal을 받고 for in으로 각기
# 자식 클래스를 호출한다.

# %% [markdown]
# ### [3번 문제]
# #### 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %% [markdown]
# - 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#
#   - count: Counter 인스턴스가 지니는 초기 정수 값
#   - step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
#     - c = Counter(10)
#     - d = Counter(10, 2)
#
#
# - 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 __str__() 메소드를 Counter 클래스 내에 구현하시오.
#
#   - print(c)
#   - [Count (step: 1)] 10
#   - print(d)
#   - [Count (step: 2)] 10
#
#
# - 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#
#   - c.incr()
#   - d.incr()
#   - print(c)
#   - [Count (step: 1)] 11
#   - print(d)
#   - [Count (step: 2)] 12
#
#
# - 요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#
#   - c()
#   - d()
#   - print(c)
#   - [Count (step: 1)] 12
#   - print(d)
#   - [Count (step: 2)] 14
#
#
# - 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#   - c = c + 5
#   - d = d - 5
#   - print(c)
#   - [Count (step: 1)] 17
#   - print(d)
#   - [Count (step: 2)] 9
#
#
# - 요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#
#   - print(c) > 10
#   - True
#   - print(d) > 10
#   - False
#   - print(c) < 10
#   - False
#   - print(d) < 10
#   - True
#   - print(c) == 17
#   - True
#   - print(d) != 9
#   -False

# %%
class Counter:
    def __init__(self, count, step = 1):
        self.count = count
        self.step = step
    def __str__(self):
        return '[Count (step: ' + str(self.step) + ')] ' + str(self.count)
    def __call__(self):
        self.count = self.count + self.step
    def __add__(self, other):
        self.count = self.count + other
        return self
    def __sub__(self, other):
        self.count = self.count - other
        return self
    def __eq__(self, other):
        return self.count == other
    def __ne__(self, other):
        return self.count != other
    def __gt__(self, other):
        return self.count > other
    def __lt__(self, other):
        return self.count < other
#    def __cmp__(self, other):
#        return self.count - other
    def incr(self):
        self.count = self.count + self.step

# Requirement 1
c = Counter(10)
d = Counter(10, 2)

# Requirement 2
print(c)
print(d)

# Requirement 3
c.incr()
d.incr()
print(c)
print(d)

# Requirement 4
c()
d()
print(c)
print(d)

# Requirement 5
c = c + 5
d = d - 5
print(c)
print(d)

# Requirement 6
print (c > 10)
print (d > 10)
print (c < 10)
print (d < 10)
print (c == 17)
print (d != 9)
# Out:
# [Count (step: 1)] 10
# [Count (step: 2)] 10
# [Count (step: 1)] 11
# [Count (step: 2)] 12
# [Count (step: 1)] 12
# [Count (step: 2)] 14
# [Count (step: 1)] 17
# [Count (step: 2)] 9
# True
# False
# False
# True
# True
# False

# %% [markdown]
# #### [설명]
#
#  요구 사항이 기본적인 기능을 구현하는 것이기 때문에 코드로 간단하게 구현할 수 있었다. 특이 사항이 있다고 하면 self를 적극 활용하였다는 점이다.
#  단, 기존의 __cmp__을 활용하여 대소, equal 구분을 하려고 했는데 python3으로 바뀌면서 내장함수 형식이 바뀌어 __eq__, __ne__, __gt__, __t__으로 나누어 각기 다른 비교를 할 수 있도록 하였다.

# %% [markdown]
# ###  [4번 문제]
#
# - 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# #### [설명]
#
# - 클래스 MySet은 리스트 클래스를 상속받은 클래스다. 크게 init()이라는 클래스 생성자, str()이라는 표준 출력할 때 호출되는 함수, 그리고 MySet 클래스가 가지고 있는 멤버 변수인 리스트의 중복을 제거하는 eliminate_duplicate(l)함수가 있다.
# - 먼저 init()이라는 생성자 함수부터 살펴보면, 인자로 받은 리스트를 멤버변수 리스트에 추가한 뒤, 추가된 리스트의 속성들 중 중복되는 속성을 제거하는 eliminamte_duplicate함수를 재귀호출한다. 일반적인 리스트에서 중복되는 속성이 없는 리스트, 즉 집합(Set) 자료를 생성하게 된다.
#
# - str() 함수는 슬라이싱을 이용하여 멤버변수인 리스트(사실상 집합)의 내용을 출력하는 간단한 내용의 코드로 이루어져 있다.
# - MySet 클래스의 가장 핵심적인 함수인 eliminate_duplicate() 함수도 별 내용은 없다. 비어있는 리스트 자료에 중복된 속성이 존재할 지도 모르는 멤버 변수 리스트를 하나씩 넣는데, 중복된 속성 값이 들어가지 않도록 따져가며 넣는다. 그리고 기존의 멤버변수 리스트의 내용을 비운 뒤, 새로 만든 리스트로 빈 자리를 채운다. 공간복잡도는 둘째 치고, 직관적으로 이해하기에는 쉬운 코드가 아닐 수 없다.

# %% [markdown]
# ### [5번 문제]
#
# - 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)

# %% [markdown]
# - 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
# > s = s | t
# > print s
#
# MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
#
# - 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
# > s = MySet([1, 2, 3])
# > t = MySet([3, 4, 5])
# > s = s & t
# > print s
#
# MySet: {3}
#
# - 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
# > s = MySet([1, 2, 3])
# > t = MySet([3, 4, 5])
# > s = s - t
# > print s
#
# MySet: {1, 2}

# %%
#/usr/local/bin/python
# coding: utf-8

class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)

    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + ", "
        result = result[0:len(result) - 2] + "}"
        return result
    
    def __or__(self, otherList):
        for e in otherList:
            self.append(e)
            MySet.eliminate_duplicate(self)
        return self

    def __and__(self, otherList):
        s = []
        for e in otherList:
            if e in self:
                s.append(e)
        return MySet(s)
    
    def __sub__(self, otherList):
        s = []
        for e in self:
            if e not in otherList:
                s.append(e)
        return MySet(s)	

    @staticmethod
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
    
    # Requirement 1
    s = s | t
    print(s)
    
    # Requirement 2
    s = MySet([1, 2, 3])
    t = MySet([3, 4, 5])
    s = s & t
    print(s)
    
    # RequireMent 3
    s = MySet([1, 2, 3])
    t = MySet([3, 4, 5])
    s = s - t
    print(s)
# Out:
# MySet: {1, 2, 3}
# MySet: {2, 3, 4, 5, 6, 7, 8, 9}
# MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# MySet: {3}
# MySet: {1, 2}

# %% [markdown]
# #### [설명]
# - or, and, sub에 대한 오버로딩을 하였다. 각각 원소의 중복 여부에 따라 원소를 구성하기 때문에 in과 not in 키워드를 중점적으로 사용하여 기능을 구현하였다.

# %% [markdown]
# ### [6번 문제]
#
# - 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %% [markdown]
# > s = MySet([1, 2, 3, 4, 5, 6])
# > - print(len(s))
# > - 6
#
# > print(bool(s))
# > - True
#
# > print(2 in s)
# > - True

# %%
#/usr/local/bin/python
# coding: utf-8

class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)

    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + ", "
        result = result[0:len(result) - 2] + "}"
        return result

    def __or__(self, otherList):
        for e in otherList:
            self.append(e)
            MySet.eliminate_duplicate(self)
        return self

    def __and__(self, otherList):
        s = []
        for e in otherList:
            if e in self:
                s.append(e)
        return MySet(s)
    
    def __sub__(self, otherList):
        s = []
        for e in self:
            if e not in otherList:
                s.append(e)
        return MySet(s)	

    @staticmethod
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

if __name__ == "__main__":
    s = MySet([1, 2, 3, 4, 5, 6])
    print(len(s))
    print(bool(s))
    print(2 in s)
# Out:
# 6
# True
# True

# %% [markdown]
# - [설명]
#
# 해당 클래스는 list를 상속받았기 때문에, 해당 클래스에서 정의되지 않은 메소드는 부모 클래스의 이름 공간을 참조하게 된다. 따라서 에러가 발생하지 않고 list에 정의된 메소드인 len(), bool() 내장함수와 in키워드 사용 예제가 잘 작동하는 것이다.

# %%
stopword = ["a", "about","above","across","after","again","against","all","almost","alone","along","already","also",
"although","always","among","an","and","another","any","anybody","anyone","anything","anywhere","are","area","areas",
"around","as","ask","asked","asking","asks","at","away","b","back","backed","backing","backs","be","became","because",
"become","becomes","been","before","began","behind","being","beings","best","better","between","big","both","but","by",
"c","came","can","cannot","case","cases","certain","certainly","clear","clearly","come","could","d","did","differ",
"different","differently","do","does","done","down","downed","downing","downs","during","e","each","early",
"either","end","ended","ending","ends","enough","even","evenly","ever","every","everybody","everyone","everything",
"everywhere","f","face","faces","fact","facts","far","felt","few","find","finds","first","for","four","from","full",
"fully","further","furthered","furthering","furthers","g","gave","general","generally","get","gets","give","given",
"gives","go","going","good","goods","got","great","greater","greatest","group","grouped","grouping","groups","h","had",
"has","have","having","he","her","here","herself","high","high","high","higher","highest","him","himself","his","how",
"however","i","if","important","in","interest","interested","interesting","interests","into","is","it","its","itself",
"j","just","k","keep","keeps","kind","knew","know","known","knows","l","large","largely","last","later","latest","least",
"less","let","lets","like","likely","long","longer","longest","m","made","make","making","man","many","may","me","member"
"members","men","might","more","most","mostly","mr","mrs","much","must","my","myself","n","necessary","need","needed",
"needing","needs","never","new","newer","newest","next","no","nobody","non","noone","not","nothing","now",
"nowhere","number","numbers","o","of","off","often","old","older","oldest","on","once","one","only","open","opened",
"opening","opens","or","order","ordered","ordering","orders","other","others","our","out","over","p","part","parted",
"parting","parts","per","perhaps","place","places","point","pointed","pointing","points","possible","present","presented",
"presenting","presents","problem","problems","put","puts","q","quite","r","rather","really","right","room",
"rooms","s","said","same","saw","say","says","second","seconds","see","seem","seemed","seeming","seems","sees","several",
"shall","she","should","show","showed","showing","shows","side","sides","since","small","smaller","smallest","so","some",
"somebody","someone","something","somewhere","state","states","still","such","sure","t","take","taken","than",
"that","the","their","them","then","there","therefore","these","they","thing","things","think","thinks","this","those",
"though","thought","thoughts","three","through","thus","to","today","together","too","took","toward","turn","turned",
"turning","turns","two","u","under","until","up","upon","us","use","used","uses","v","very","w","want","wanted",
"wanting","wants","was","way","ways","we","well","wells","went","were","what","when","where","whether","which","while",
"who","whole","whose","why","will","with","within","without","work","worked","working","works","would","x","y","year",
"years","yet","you","young","younger","youngest","your","yours","z"]

# %% [markdown]
# ### [7번 문제]
#
# 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3을 다시 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.
#
# - 1) 새로운 클래스 WebWordsFrequency를 정의하시오.
#   - 이전 Assignment 4에서 고려했던 pickle 모듈등은 전혀 고려하지 마시오.
#     - 즉, 하드디스크에 저장하고 다시 로드하는 기능은 본 숙제에는 배제하시오.
#   - Assignment 4에서 고려했던 영어 불용어 처리는 적용하시오.
#   - Assignment 4에서 처럼 국문 사이트가 아닌 영어 사이트만을 고려하여 아래 사항을 코딩하시오.
#
# - 2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#    - w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com')
#    - w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
#    - w3 = WebWordsFrequency()
#
#
# - 3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#
#   - 반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#     - w1.addUrl('https://github.com')
#     -  w3.addUrl('http://stackoverflow.com')
#
#
# - 4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#
#   - 반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#     - w1.removeUrl('http://www.cnn.com')
#     - w2.removeUrl('http://stackoverflow.com')
#
#
# - 5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#   - w1.listUrls()
#         http://www.times.com
#         https://www.amazon.com
#         https://github.com
#
#
# - 6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#
#   - 만약 등록된 URL이 없다면 공백 사전을 반환
#      w1.getWordsFrequency()
# {'hello': 8, 'site': 12, 'world': 2, 'science': 11, 'program': 1, 'python': 1}
#
#
# - 7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#
#   - w1.getMaxFreqencyWords()
#     site
#
#   - 최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#      - w2.getMaxFreqencyWords()
#     site
#     science
#
#  - 만약 등록된 URL이 없다면 None을 반환
#
#
# - 8) 임의의 단어 1개를 파라미터로 받는 searchUrlByWord() 메소드를 구현하여 유사도가 높은 웹 사이트를 출력하시오.
#
#   - w1.searchUrlByWord("news")
#     http://www.cnn.com
#
# - 파라미터로 받은 단어와 유사도가 동일한 URL이 여러 개이면 해당 URL을 모두 출력하시오.

# %%
#!/usr/local/bin/python
# coding: utf-8
import sys, os, urllib, string, requests
from urllib.request import urlopen

def printDictForKorKey(d):
    if len(d) == 0:
        print({})
    else:
        print('{',)
        for key, value in d.items():
            print('\'' + key + '\': ', value, ',',)
        print('}')


# Url을 파싱하여 단어 및 단어 개수를 사전 형태로 반환하는 함수다.
def parsingUrl(url):
    #s = urllib.urlopen(url).read()
    s = str(urlopen(url).read())
    n = 0
    pivot = 0
    while(n < len(s)):
        if(s[n] == "<" and s[n + 1 : n + 7].lower() == "script"):
            pivot = n
            while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 8].lower() != "script"):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+9:]
    
        elif(s[n] == "<" and s[n + 1 : n + 6].lower() == "style"):
            pivot = n
            while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 7].lower() != "style"):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+8:]

        elif(s[n] == '<'):
            pivot = n
            while(s[pivot] != '>'):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+1:]
        elif(s[n] == '\n' or s[n] == '\t'):
            s = s[0:n] + ' ' + s[n+1:]
        elif(s[n] in string.punctuation) :
            s = s[0:n] + s[n+1:]
        else:
            n += 1

    s2 = s.split()
    s3 = ' '.join(s2)
    n = 0
    D = {}
    i = 0
#    while(n < len(s2)):
#       while(i < len(stopword)):
#            if(s2[n] == stopword[i]):
#                s2.remove(s2[n])
#            i = i+1
#        n = n+1
    
    while(n < len(s2)):
        if(s2[n] in D.keys()):
            D[s2[n]] += 1
        else:
            D[s2[n]] = 1
        n += 1
    
    return D


# 웹사이트 상의 단어 빈도에 대한 정보를 다루는 클래스다.
class WebWordsFrequency:

# 생성자
    def __init__(self, *urls):
        self.urlList = list(urls)

    # Url 추가
    def addUrl(self, strUrl):
        self.urlList.append(strUrl)

    # Url 삭제
    def removeUrl(self, strUrl):
        self.urlList.remove(strUrl)

    # Url 목록 출력
    def listUrls(self):
        for e in self.urlList:
            print(e)

    # 저장된 웹사이트 url에 기반한 단어 빈도 사전 출력
    def getWordsFrequency(self):
        totalDict = {}

        for urls in self.urlList:
            D = parsingUrl(urls)
            keys = totalDict.keys()
            for key, value in D.items():
                if(key in keys):
                    totalDict[key] += value
                else:
                    totalDict[key] = value
        return totalDict

    # 최다 빈도 출현 단어 출력
    def getMaxFrequencyWords(self):
        if len(self.urlList) == 0:
            return None
        else:
            maxValues = 0
            maxKeys = []
            maxUrls = ' '
            
            totalDict = {}
    
            for urls in self.urlList:
                D = parsingUrl(urls)
                keys = totalDict.keys()
                for key, value in D.items():
                    if(key in keys):
                        totalDict[key] += value
                    else:
                        totalDict[key] = value
        
            for key, value in totalDict.items():
                if(maxValues < value):
                    maxValues = value
                    maxKeys = [key]
                elif(maxValues == value):
                    maxKeys.append(key)
            
            print("<Maximum Frequency Word List>")
            print(" - Frequency : ", maxValues)
            for k in maxKeys:
                print(k)
            print()

if __name__ == "__main__":
    # Requirement 1
    w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
    w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
    w3 = WebWordsFrequency()

    # Requirement 2
    w1.addUrl('https://github.com')
    w2.addUrl('http://stackoverflow.com')
    w3.addUrl('http://stackoverflow.com')

    # Requirement 3
    w1.removeUrl('http://www.cnn.com')
    w2.removeUrl('http://stackoverflow.com')

    # Requirement 4
    print("w1.listUrls() : ")
    w1.listUrls()
    print("w2.listUrls() : ")
    w2.listUrls()
    print("w3.listUrls() : ")
    w3.listUrls()

    # Requirement 5
    printDictForKorKey(w1.getWordsFrequency())

    # Requirement 6
    w1.getMaxFrequencyWords()
    w2.getMaxFrequencyWords()
# Out:
# w1.listUrls() :
# http://www.times.com
# https://github.com
# w2.listUrls() :
# http://www.cnn.com
# http://www.times.com
# w3.listUrls() :
# http://stackoverflow.com
# {
# 'b':  1 ,
# 'n':  2935 ,
# 'The':  48 ,
# 'New':  29 ,
# 'York':  16 ,
# 'Times':  16 ,
# 'Breaking':  1 ,
# 'News':  7 ,
# 'World':  6 ,
# 'Multimedia':  2 ,
# 'nn':  477 ,
# 'NYTimescom':  2 ,
# 'no':  2 ,
# 'longer':  1 ,
# 'supports':  1 ,
# 'Internet':  2 ,
# 'Explorer':  1 ,
# '9':  1 ,
# 'or':  11 ,
# 'earlier':  1 ,
# 'Please':  1 ,
# 'upgrade':  1 ,
# 'your':  18 ,
# 'browser':  1 ,
# 'LEARN':  1 ,
# 'MORE':  1 ,
# 'xc2xbb':  4 ,
# 'Sections':  4 ,
# 'Search':  7 ,
# 'Skip':  3 ,
# 'to':  78 ,
# 'content':  2 ,
# 'navigation':  1 ,
# 'Subscribe':  5 ,
# 'Now':  3 ,
# 'Log':  1 ,
# 'In':  7 ,
# '0':  1 ,
# 'Settings':  1 ,
# 'English':  1 ,
# 'xe4xb8xadxe6x96x87':  1 ,
# 'Chinese':  1 ,
# 'Espaxc3xb1ol':  1 ,
# 'Tuesday':  2 ,
# 'December':  1 ,
# '12':  1 ,
# '2017':  6 ,
# 'Todayxe2x80x99s':  2 ,
# 'Paper':  2 ,
# 'Video':  6 ,
# 'Quick':  1 ,
# 'Site':  10 ,
# 'Navigation':  7 ,
# 'US':  8 ,
# 'Politics':  4 ,
# 'NY':  2 ,
# 'Business':  6 ,
# 'Opinion':  10 ,
# 'Tech':  3 ,
# 'Science':  3 ,
# 'Health':  7 ,
# 'Sports':  5 ,
# 'Arts':  6 ,
# 'Style':  4 ,
# 'Food':  4 ,
# 'Travel':  3 ,
# 'Magazine':  7 ,
# 'T':  4 ,
# 'Real':  5 ,
# 'Estate':  5 ,
# 'all':  3 ,
# 'Close':  1 ,
# 'search':  1 ,
# 'Clear':  1 ,
# 'this':  3 ,
# 'text':  1 ,
# 'input':  1 ,
# 'Go':  4 ,
# 'nnn':  12 ,
# 'Mobile':  3 ,
# 'rn':  50 ,
# 'rnrnrnrnrn':  1 ,
# 'rnrn':  27 ,
# 'Top':  3 ,
# 'What':  6 ,
# 'Watch':  2 ,
# 'For':  3 ,
# 'as':  5 ,
# 'Voters':  1 ,
# 'Choose':  1 ,
# 'Senator':  1 ,
# 'in':  42 ,
# 'Alabama':  6 ,
# 'By':  23 ,
# 'JONATHAN':  1 ,
# 'MARTIN':  1 ,
# '500':  4 ,
# 'AM':  10 ,
# 'ET':  10 ,
# 'special':  1 ,
# 'election':  1 ,
# 'between':  1 ,
# 'Roy':  7 ,
# 'S':  1 ,
# 'Moore':  5 ,
# 'and':  64 ,
# 'Doug':  1 ,
# 'Jones':  1 ,
# 'carries':  1 ,
# 'immense':  1 ,
# 'implications':  1 ,
# 'for':  47 ,
# 'both':  2 ,
# 'parties':  1 ,
# 'President':  2 ,
# 'Trump':  5 ,
# 'Turnout':  1 ,
# 'by':  9 ,
# 'key':  1 ,
# 'groups':  1 ,
# 'on':  14 ,
# 'sides':  1 ,
# 'could':  1 ,
# 'be':  2 ,
# 'decisive':  1 ,
# 'nntnt':  9 ,
# 'Candidates':  1 ,
# 'Hold':  1 ,
# 'Final':  1 ,
# 'Rallies':  1 ,
# 'Upshot':  2 ,
# 'Why':  7 ,
# 'No':  5 ,
# 'One':  3 ,
# 'Knows':  2 ,
# 'Will':  5 ,
# 'Happen':  2 ,
# 'Herexe2x80x99s':  3 ,
# 'How':  6 ,
# 'Became':  1 ,
# 'Mired':  2 ,
# 'a':  57 ,
# 'Scandal':  2 ,
# 'Manhattan':  1 ,
# 'Bombing':  5 ,
# 'Suspect':  2 ,
# 'Leaves':  2 ,
# 'Trail':  2 ,
# 'of':  60 ,
# 'Mystery':  2 ,
# 'ALAN':  1 ,
# 'FEUER':  1 ,
# 'As':  1 ,
# 'the':  85 ,
# 'authorities':  1 ,
# 'searched':  1 ,
# 'clues':  1 ,
# 'those':  3 ,
# 'who':  7 ,
# 'knew':  1 ,
# 'Akayed':  1 ,
# 'Ullah':  1 ,
# 'described':  1 ,
# 'an':  7 ,
# 'ordinary':  1 ,
# 'immigrant':  1 ,
# 'life':  2 ,
# 'Brooklyn':  1 ,
# 'Bomber':  3 ,
# 'Was':  1 ,
# 'Retaliating':  1 ,
# 'Attacks':  1 ,
# 'ISIS':  1 ,
# 'Officials':  1 ,
# 'Say':  2 ,
# '125':  1 ,
# 'Surveillance':  1 ,
# 'Shows':  2 ,
# 'Bomb':  2 ,
# 'Going':  2 ,
# 'Off':  3 ,
# 'MALACHY':  1 ,
# 'BROWNE':  1 ,
# 'CHRIS':  2 ,
# 'CIRILLO':  1 ,
# 'BARBARA':  1 ,
# 'MARCOLINI':  1 ,
# 'About':  7 ,
# 'After':  2 ,
# 'Doubling':  1 ,
# 'Down':  1 ,
# 'Everyday':  1 ,
# 'JIM':  1 ,
# 'DWYER':  1 ,
# 'man':  2 ,
# 'homemade':  1 ,
# 'suicide':  1 ,
# 'vest':  1 ,
# 'blew':  1 ,
# 'himself':  1 ,
# 'up':  8 ,
# 'near':  1 ,
# 'Square':  3 ,
# 'Yorkers':  3 ,
# 'kept':  1 ,
# 'their':  6 ,
# 'fears':  1 ,
# 'at':  12 ,
# 'bay':  1 ,
# 'subway':  1 ,
# 'turnstiles':  1 ,
# 'spinning':  1 ,
# 'More':  7 ,
# 'Coverage':  1 ,
# 'Subway':  3 ,
# 'Deadly':  1 ,
# 'Tactic':  1 ,
# 'Imported':  1 ,
# 'From':  11 ,
# 'Overseas':  1 ,
# 'Crude':  1 ,
# 'Pipe':  1 ,
# 'Malfunctioned':  1 ,
# 'Authorities':  1 ,
# 'Some':  4 ,
# 'Trumpxe2x80x99s':  4 ,
# 'Accusers':  1 ,
# 'Renew':  1 ,
# 'Misconduct':  6 ,
# 'Charges':  1 ,
# 'MICHAEL':  1 ,
# 'D':  1 ,
# 'SHEAR':  1 ,
# 'Several':  1 ,
# 'women':  1 ,
# 'said':  2 ,
# 'they':  5 ,
# 'hoped':  1 ,
# 'taken':  1 ,
# 'more':  5 ,
# 'seriously':  1 ,
# 'after':  3 ,
# 'torrent':  1 ,
# 'allegations':  2 ,
# 'that':  10 ,
# 'have':  6 ,
# 'toppled':  1 ,
# 'careers':  1 ,
# 'men':  2 ,
# 'news':  2 ,
# 'media':  1 ,
# 'business':  3 ,
# 'politics':  2 ,
# 'Tawdry':  1 ,
# 'Tales':  1 ,
# 'Depict':  1 ,
# 'Congressmanxe2x80x99s':  1 ,
# 'Frat':  1 ,
# 'House':  2 ,
# 'Hill':  1 ,
# 'SHERYL':  1 ,
# 'GAY':  1 ,
# 'STOLBERG':  1 ,
# 'Former':  1 ,
# 'aides':  1 ,
# 'Blake':  1 ,
# 'Farenthold':  1 ,
# 'say':  1 ,
# 'Texas':  1 ,
# 'Republican':  1 ,
# 'runs':  1 ,
# 'epitome':  1 ,
# 'hostile':  1 ,
# 'workplace':  1 ,
# 'But':  3 ,
# 'despite':  1 ,
# 'open':  3 ,
# 'ethics':  1 ,
# 'inquiry':  1 ,
# 'few':  2 ,
# 'Republicans':  1 ,
# 'called':  2 ,
# 'his':  4 ,
# 'resignation':  1 ,
# 'Ryan':  2 ,
# 'Lizza':  1 ,
# 'Fired':  1 ,
# 'Yorker':  1 ,
# 'Over':  5 ,
# 'Sexual':  7 ,
# 'Allegation':  1 ,
# 'With':  9 ,
# 'Harassment':  3 ,
# 'Cases':  4 ,
# 'HR':  2 ,
# 'Is':  11 ,
# 'Often':  1 ,
# 'Caught':  1 ,
# 'Middle':  1 ,
# 'NOAM':  1 ,
# 'SCHEIBER':  1 ,
# 'JULIE':  1 ,
# 'CRESWELL':  1 ,
# '533':  1 ,
# 'Human':  1 ,
# 'resources':  1 ,
# 'departments':  1 ,
# 'face':  1 ,
# 'quandary':  1 ,
# 'protect':  2 ,
# 'employees':  1 ,
# 'bring':  1 ,
# 'complaints':  1 ,
# 'companies':  1 ,
# 'employ':  1 ,
# 'them':  4 ,
# 'Hall':  1 ,
# 'Famer':  1 ,
# 'Faulk':  3 ,
# 'Among':  1 ,
# '3':  1 ,
# 'Suspended':  2 ,
# 'NFL':  2 ,
# 'Network':  2 ,
# 'KEVIN':  1 ,
# 'DRAPER':  1 ,
# '234':  1 ,
# 'Marshall':  3 ,
# 'Heath':  1 ,
# 'Evans':  1 ,
# 'Ike':  1 ,
# 'Taylor':  2 ,
# 'were':  1 ,
# 'suspended':  1 ,
# 'over':  1 ,
# 'sexual':  1 ,
# 'harassment':  1 ,
# 'assault':  1 ,
# 'lawsuit':  1 ,
# 'filed':  1 ,
# 'former':  1 ,
# 'wardrobe':  1 ,
# 'stylist':  1 ,
# 'company':  2 ,
# 'Mario':  2 ,
# 'Batali':  2 ,
# 'Steps':  2 ,
# 'Away':  2 ,
# 'Restaurants':  2 ,
# 'Amid':  3 ,
# 'Allegations':  3 ,
# 'Bill':  4 ,
# 'Rolls':  2 ,
# 'Back':  2 ,
# 'Safeguards':  2 ,
# 'Higher':  2 ,
# 'Education':  7 ,
# 'ERICA':  1 ,
# 'L':  1 ,
# 'GREEN':  1 ,
# 'A':  8 ,
# 'rewrite':  1 ,
# 'law':  1 ,
# 'governing':  1 ,
# 'higher':  1 ,
# 'education':  1 ,
# 'would':  2 ,
# 'dismantle':  1 ,
# 'several':  2 ,
# 'regulations':  2 ,
# 'imposed':  1 ,
# 'Obama':  1 ,
# 'administration':  1 ,
# 'control':  1 ,
# 'forprofit':  1 ,
# 'colleges':  1 ,
# 'Got':  1 ,
# 'confidential':  1 ,
# 'tip':  1 ,
# 'offers':  1 ,
# 'ways':  1 ,
# 'get':  2 ,
# 'touch':  1 ,
# 'with':  9 ,
# 'provide':  1 ,
# 'materials':  1 ,
# 'our':  2 ,
# 'journalists':  2 ,
# 'Learn':  6 ,
# 'To':  1 ,
# 'Test':  1 ,
# 'Climate':  1 ,
# 'Disasters':  1 ,
# 'Break':  1 ,
# 'Burn':  1 ,
# 'Throw':  1 ,
# 'Stuff':  1 ,
# 'team':  3 ,
# 'researchers':  1 ,
# 'is':  7 ,
# 'destroying':  1 ,
# 'things':  1 ,
# 'help':  8 ,
# 'insurers':  1 ,
# 'manage':  2 ,
# 'increasing':  1 ,
# 'risks':  1 ,
# 'extreme':  2 ,
# 'weather':  1 ,
# 'HIROKO':  1 ,
# 'TABUCHI':  1 ,
# 'Your':  5 ,
# 'Briefing':  3 ,
# 'STANFORD':  1 ,
# '623':  1 ,
# 'what':  2 ,
# 'you':  19 ,
# 'need':  5 ,
# 'know':  2 ,
# 'start':  2 ,
# 'day':  1 ,
# 'Today':  3 ,
# 'We':  4 ,
# 'Know':  3 ,
# 'rnrnrn':  6 ,
# 'Daily':  4 ,
# 'Moorexe2x80x99s':  1 ,
# 'History':  1 ,
# 'Controversy':  1 ,
# 'built':  1 ,
# 'legal':  1 ,
# 'career':  1 ,
# 'conservative':  1 ,
# 'crusader':  1 ,
# 'faith':  1 ,
# 'Those':  1 ,
# 'battles':  1 ,
# 'may':  3 ,
# 'him':  1 ,
# 'voters':  1 ,
# 'head':  1 ,
# 'polls':  1 ,
# 'Audio':  1 ,
# 'Follow':  1 ,
# 'Apple':  1 ,
# 'Podcasts':  1 ,
# 'Google':  2 ,
# 'Play':  3 ,
# 'Music':  2 ,
# 'Radio':  1 ,
# 'Public':  1 ,
# 'RSS':  1 ,
# 'Feed':  1 ,
# 'rnt':  1 ,
# 'Smarter':  2 ,
# 'Living':  4 ,
# 'You':  6 ,
# 'Need':  2 ,
# 'Flu':  3 ,
# 'Shot':  2 ,
# 'Every':  1 ,
# 'Year':  1 ,
# 'TARA':  1 ,
# 'HAELLE':  1 ,
# '245':  1 ,
# 'probably':  1 ,
# 'flu':  2 ,
# 'shot':  1 ,
# 'every':  1 ,
# 'season':  2 ,
# 'but':  5 ,
# 'herexe2x80x99s':  1 ,
# 'why':  2 ,
# 'xe2x80x94':  3 ,
# 'itxe2x80x99s':  1 ,
# 'so':  3 ,
# 'important':  1 ,
# 'Make':  2 ,
# 'Sufganiyot':  1 ,
# 'Jelly':  1 ,
# 'Doughnuts':  1 ,
# 'Hannukah':  1 ,
# 'Fragrant':  1 ,
# 'sugar':  1 ,
# 'jam':  1 ,
# 'become':  1 ,
# 'sweeter':  1 ,
# 'symbol':  1 ,
# 'holiday':  1 ,
# 'especially':  1 ,
# 'children':  1 ,
# '300':  1 ,
# 'gifts':  1 ,
# '75':  2 ,
# 'editors':  1 ,
# '15':  3 ,
# 'categories':  1 ,
# 'Holiday':  4 ,
# 'Gift':  3 ,
# 'Guide':  6 ,
# 'Journalism':  1 ,
# 'matters':  1 ,
# 'essential':  1 ,
# 'than':  4 ,
# 'ever':  1 ,
# 'Russia':  1 ,
# 'Fanned':  1 ,
# 'Conspiracy':  1 ,
# 'Theories':  1 ,
# 'AIDS':  3 ,
# 'LINDA':  1 ,
# 'QIU':  1 ,
# '1980s':  1 ,
# 'Soviet':  1 ,
# 'disinformation':  1 ,
# 'campaign':  1 ,
# 'seeded':  1 ,
# 'conspiracy':  1 ,
# 'theory':  1 ,
# 'about':  9 ,
# 'origins':  1 ,
# 'virus':  1 ,
# 'causes':  1 ,
# 'serving':  1 ,
# 'lesson':  1 ,
# 'Russiaxe2x80x99s':  1 ,
# 'similar':  1 ,
# 'efforts':  1 ,
# 'today':  1 ,
# 'Migrants':  2 ,
# 'Answer':  1 ,
# 'Europexe2x80x99s':  1 ,
# 'Thirst':  1 ,
# 'Cheap':  1 ,
# 'Labor':  3 ,
# 'LIZ':  1 ,
# 'ALDERMAN':  1 ,
# 'Employment':  1 ,
# 'agencies':  1 ,
# 'are':  2 ,
# 'recruiting':  1 ,
# 'thousands':  1 ,
# 'migrants':  1 ,
# 'Foxconn':  1 ,
# 'other':  2 ,
# 'businesses':  2 ,
# 'conditions':  1 ,
# 'pay':  1 ,
# 'incountry':  1 ,
# 'nationals':  1 ,
# 'accept':  1 ,
# 'Brazil':  1 ,
# 'Fights':  1 ,
# 'HIV':  1 ,
# 'Spike':  1 ,
# 'Free':  1 ,
# 'Preventive':  1 ,
# 'Drug':  1 ,
# 'SHASTA':  1 ,
# 'DARLINGTON':  1 ,
# 'country':  1 ,
# 'first':  2 ,
# 'Latin':  1 ,
# 'America':  2 ,
# 'make':  3 ,
# 'blue':  1 ,
# 'pill':  1 ,
# 'PrEP':  1 ,
# 'integral':  1 ,
# 'part':  1 ,
# 'its':  4 ,
# 'health':  1 ,
# 'care':  1 ,
# 'policy':  4 ,
# 'California':  1 ,
# 'Mixed':  1 ,
# 'Results':  1 ,
# 'Rules':  1 ,
# 'Meant':  1 ,
# 'Stop':  3 ,
# 'Fires':  1 ,
# 'ADAM':  1 ,
# 'NAGOURNEY':  1 ,
# 'THOMAS':  1 ,
# 'FULLER':  1 ,
# '350':  1 ,
# 'While':  1 ,
# 'can':  3 ,
# 'certainly':  1 ,
# 'against':  1 ,
# 'slowmoving':  1 ,
# 'fires':  2 ,
# 'proved':  1 ,
# 'match':  1 ,
# 'highwind':  1 ,
# 'made':  1 ,
# 'destructive':  1 ,
# 'GOP':  1 ,
# 'Tax':  3 ,
# 'Would':  2 ,
# 'Affect':  1 ,
# 'Wildfire':  1 ,
# 'Victims':  1 ,
# 'Christoph':  1 ,
# 'Waltz':  1 ,
# 'Moves':  1 ,
# 'Tarantino':  1 ,
# 'Verdi':  1 ,
# 'CORINNA':  1 ,
# 'da':  1 ,
# 'FONSECAWOLLHEIM':  1 ,
# 'Oscarwinning':  1 ,
# 'actor':  1 ,
# 'concentrates':  1 ,
# 'subtle':  1 ,
# 'acting':  1 ,
# 'production':  1 ,
# 'xe2x80x9cFalstaffxe2x80x9d':  1 ,
# 'he':  4 ,
# 'directing':  1 ,
# 'Opera':  1 ,
# 'Vlaanderen':  1 ,
# 'Belgium':  1 ,
# 'Precious':  2 ,
# 'Gems':  2 ,
# 'Bear':  2 ,
# 'Messages':  2 ,
# 'Earthxe2x80x99s':  2 ,
# 'Molten':  2 ,
# 'Heart':  2 ,
# 'NATALIE':  1 ,
# 'ANGIER':  1 ,
# 'covet':  1 ,
# 'gemstones':  1 ,
# 'beauty':  1 ,
# 'real':  1 ,
# 'value':  1 ,
# 'lies':  1 ,
# 'tell':  1 ,
# 'scientists':  1 ,
# 'forces':  1 ,
# 'work':  11 ,
# 'deep':  2 ,
# 'underground':  1 ,
# 'De':  1 ,
# 'Blasio':  2 ,
# 'Aims':  1 ,
# 'Create':  1 ,
# 'Affordable':  2 ,
# 'Housing':  1 ,
# 'Homeless':  1 ,
# 'NIKITA':  1 ,
# 'STEWART':  1 ,
# 'Mayor':  1 ,
# 'de':  1 ,
# 'will':  2 ,
# 'announce':  1 ,
# 'plan':  1 ,
# 'geared':  1 ,
# 'toward':  1 ,
# 'converting':  1 ,
# '800':  1 ,
# 'apartments':  1 ,
# 'used':  1 ,
# 'house':  1 ,
# 'homeless':  2 ,
# 'into':  1 ,
# 'affordable':  1 ,
# 'housing':  1 ,
# 'city':  1 ,
# '360':  2 ,
# '150':  2 ,
# 'Climb':  1 ,
# 'Million':  3 ,
# 'Stairway':  1 ,
# 'Nowhere':  1 ,
# 'Forbes':  1 ,
# 'MassieHeatherwick':  1 ,
# 'Studio':  1 ,
# 'Technology':  2 ,
# 'Samsung':  1 ,
# 'Ambassador':  1 ,
# 'Britain':  1 ,
# 'Says':  1 ,
# 'He':  1 ,
# 'Hopes':  1 ,
# 'Visit':  1 ,
# 'Westfield':  2 ,
# 'Owner':  2 ,
# 'Trade':  2 ,
# 'Center':  3 ,
# 'Mall':  2 ,
# 'Be':  3 ,
# 'Sold':  4 ,
# 'Charles':  1 ,
# 'Jenkins':  1 ,
# 'Soldier':  1 ,
# 'Who':  3 ,
# 'Fled':  1 ,
# 'North':  1 ,
# 'Korea':  1 ,
# 'Dies':  4 ,
# 'EU':  1 ,
# 'Leaders':  1 ,
# 'Reject':  1 ,
# 'Netanyahu':  1 ,
# 'Jerusalem':  1 ,
# 'Recognition':  1 ,
# 'Treasury':  1 ,
# 'Defends':  1 ,
# 'Plan':  2 ,
# 'Cost':  2 ,
# 'OnePage':  1 ,
# 'Analysis':  2 ,
# 'All':  7 ,
# 'DealBook':  2 ,
# 'Newsletter':  1 ,
# 'Our':  6 ,
# 'columnist':  2 ,
# 'Andrew':  1 ,
# 'Ross':  1 ,
# 'Sorkin':  1 ,
# 'colleagues':  1 ,
# 'sense':  1 ,
# 'major':  1 ,
# 'headlines':  1 ,
# 'power':  1 ,
# 'brokers':  1 ,
# 'shape':  1 ,
# 'Get':  3 ,
# 'allnew':  1 ,
# 'newsletter':  1 ,
# 'See':  1 ,
# 'Edition':  2 ,
# 'Australian':  2 ,
# 'Lawmaker':  1 ,
# 'Quits':  1 ,
# 'Questions':  1 ,
# 'China':  2 ,
# 'Ties':  1 ,
# 'Sam':  1 ,
# 'Dastyari':  1 ,
# 'Party':  1 ,
# 'member':  1 ,
# 'faced':  1 ,
# 'accusations':  1 ,
# 'pushed':  1 ,
# 'policies':  1 ,
# 'favorable':  1 ,
# 'accepting':  1 ,
# 'money':  1 ,
# 'from':  6 ,
# 'Chineseborn':  1 ,
# 'political':  1 ,
# 'donors':  1 ,
# 'At':  2 ,
# 'Refugee':  1 ,
# 'Camp':  1 ,
# 'Mix':  1 ,
# 'Hope':  1 ,
# 'Doubts':  1 ,
# 'Plans':  1 ,
# '60':  1 ,
# 'refugees':  1 ,
# 'had':  1 ,
# 'been':  1 ,
# 'given':  1 ,
# 'appointments':  1 ,
# 'American':  1 ,
# 'officials':  1 ,
# 'travel':  1 ,
# 'ban':  1 ,
# 'might':  1 ,
# 'limit':  1 ,
# 'was':  1 ,
# 'resettled':  1 ,
# 'Eluding':  1 ,
# 'Censors':  1 ,
# 'Covers':  1 ,
# 'Southeast':  2 ,
# 'Asiaxe2x80x99s':  2 ,
# 'Literary':  1 ,
# 'Scene':  2 ,
# 'Mekong':  1 ,
# 'Reviewxe2x80x99s':  1 ,
# 'contributors':  1 ,
# 'include':  1 ,
# 'some':  1 ,
# 'bestknown':  1 ,
# 'authors':  1 ,
# 'academics':  1 ,
# 'follow':  1 ,
# 'region':  2 ,
# 'Searching':  2 ,
# 'Secret':  2 ,
# 'Ski':  3 ,
# 'Destination':  3 ,
# 'Try':  3 ,
# 'Michigan':  2 ,
# 'Skiing':  1 ,
# 'has':  3 ,
# 'long':  1 ,
# 'tradition':  1 ,
# 'state':  1 ,
# 'Visits':  1 ,
# 'three':  1 ,
# 'resorts':  1 ,
# 'case':  1 ,
# 'extended':  1 ,
# 'winter':  1 ,
# 'vacation':  1 ,
# 'Broadcom':  1 ,
# 'Deal':  1 ,
# 'Might':  1 ,
# 'Mean':  1 ,
# 'Fewer':  1 ,
# 'Jobs':  3 ,
# 'returning':  1 ,
# 'United':  1 ,
# 'States':  1 ,
# 'if':  1 ,
# 'takeover':  1 ,
# 'bid':  1 ,
# 'Qualcomm':  1 ,
# 'goes':  2 ,
# 'through':  3 ,
# 'it':  4 ,
# 'cost':  1 ,
# 'jobs':  1 ,
# 'writes':  1 ,
# 'Criticsxe2x80x99':  2 ,
# 'Picks':  1 ,
# 'Best':  6 ,
# 'Albums':  1 ,
# 'yearxe2x80x99s':  1 ,
# 'best':  1 ,
# 'albums':  1 ,
# 'came':  1 ,
# 'St':  1 ,
# 'Vincent':  1 ,
# 'Lorde':  1 ,
# 'Kendrick':  1 ,
# 'Lamar':  1 ,
# 'J':  2 ,
# 'Cole':  1 ,
# 'Julien':  1 ,
# 'Baker':  1 ,
# 'Swift':  1 ,
# 'Editorial':  3 ,
# 'Donxe2x80x99t':  3 ,
# 'Scare':  2 ,
# 'Easily':  2 ,
# 'Even':  1 ,
# 'rushhour':  1 ,
# 'blast':  1 ,
# 'fearmongers':  1 ,
# 'find':  2 ,
# 'little':  1 ,
# 'support':  2 ,
# 'populace':  1 ,
# 'adept':  1 ,
# 'keeping':  1 ,
# 'composure':  1 ,
# 'nbspComments':  2 ,
# 'Mr':  1 ,
# 'Mnuchinxe2x80x99s':  1 ,
# 'Magical':  1 ,
# 'Math':  1 ,
# 'Taxes':  1 ,
# 'Krugman':  1 ,
# 'Steve':  1 ,
# 'Mnuchin':  1 ,
# 'Pulls':  1 ,
# 'Paul':  1 ,
# 'Collins':  1 ,
# 'Edge':  1 ,
# 'Senate':  3 ,
# 'Race':  3 ,
# 'May':  3 ,
# 'Have':  1 ,
# 'Already':  1 ,
# 'Been':  1 ,
# 'Decided':  1 ,
# 'Brooks':  1 ,
# 'Whatxe2x80x99s':  1 ,
# 'Wrong':  1 ,
# 'Radicalism':  1 ,
# 'Goldberg':  1 ,
# 'White':  1 ,
# 'Supremacy':  1 ,
# 'Caucus':  1 ,
# 'Jacob':  2 ,
# 'Zuma':  2 ,
# 'Theft':  3 ,
# 'South':  2 ,
# 'Africa':  2 ,
# 'IVOR':  1 ,
# 'CHIPKIN':  1 ,
# '109':  1 ,
# 'ANC':  1 ,
# 'needs':  2 ,
# 'move':  2 ,
# 'away':  1 ,
# 'presidentxe2x80x99s':  1 ,
# 'corrupt':  1 ,
# 'look':  1 ,
# 'solutions':  1 ,
# 'not':  2 ,
# 'based':  1 ,
# 'crude':  1 ,
# 'nationalism':  1 ,
# 'racial':  1 ,
# 'essentialism':  1 ,
# 'Team':  2 ,
# 'Needs':  2 ,
# 'Lay':  2 ,
# 'Mueller':  2 ,
# 'Probe':  2 ,
# 'BOB':  1 ,
# 'BAUER':  1 ,
# 'If':  1 ,
# 'question':  1 ,
# 'impeachment':  1 ,
# 'Congress':  1 ,
# 'Ixe2x80x99m':  1 ,
# 'Not':  2 ,
# 'Convinced':  1 ,
# 'Franken':  1 ,
# 'Should':  1 ,
# 'Quit':  1 ,
# 'Yes':  1 ,
# 'Truth':  1 ,
# 'Still':  1 ,
# 'Matters':  1 ,
# 'User':  1 ,
# 'Subscriptions':  5 ,
# 'When':  3 ,
# 'Projectile':  3 ,
# 'TwobyFour':  3 ,
# 'Dayxe2x80x99s':  3 ,
# 'Work':  5 ,
# 'Long':  2 ,
# 'Ferret':  2 ,
# 'Out':  4 ,
# 'xe2x80x98Salvator':  2 ,
# 'Mundixe2x80x99':  2 ,
# 'Buyer':  2 ,
# 'Insider':  2 ,
# 'raquo':  33 ,
# 'nt':  15 ,
# 't':  4 ,
# 'tt':  2 ,
# 'Crossword':  4 ,
# 'nttt':  8 ,
# 'ntttt':  6 ,
# 'Todayrsquos':  2 ,
# 'Puzzle':  2 ,
# 'nttttt':  2 ,
# 'Wordplay':  1 ,
# 'Watching':  1 ,
# 'Neediest':  2 ,
# 'Working':  1 ,
# 'Philanthropy':  1 ,
# 'Then':  1 ,
# 'Finding':  1 ,
# 'Himself':  1 ,
# 'Kenneth':  1 ,
# 'Dillard':  1 ,
# 'Jr':  1 ,
# '68':  1 ,
# 'worked':  1 ,
# 'nonprofit':  1 ,
# 'organizations':  1 ,
# 'much':  1 ,
# 'when':  1 ,
# 'lost':  1 ,
# 'job':  2 ,
# 'struggled':  1 ,
# 'became':  1 ,
# '106th':  1 ,
# 'year':  1 ,
# 'Fund':  1 ,
# 'provided':  1 ,
# 'direct':  1 ,
# 'assistance':  1 ,
# 'struggling':  1 ,
# 'beyond':  1 ,
# 'Donate':  1 ,
# 'now':  1 ,
# 'Advertisers':  1 ,
# 'Loading':  2 ,
# 'times':  1 ,
# 'video':  1 ,
# 'explore':  1 ,
# 'videos':  1 ,
# 'Player':  2 ,
# 'Inside':  2 ,
# 'Nytimescom':  1 ,
# 'previous':  1 ,
# 'story':  2 ,
# 'next':  1 ,
# 'Television':  3 ,
# 'Late':  1 ,
# 'Night':  1 ,
# 'Taunting':  1 ,
# 'xe2x80x98Failedxe2x80x99':  1 ,
# 'Sunday':  2 ,
# 'Review':  5 ,
# 'Veterans':  1 ,
# 'Path':  1 ,
# 'Healing':  1 ,
# 'xe2x80x98Moral':  1 ,
# 'Injuryxe2x80x99':  1 ,
# 'Mind':  1 ,
# 'Loneliness':  1 ,
# 'Affects':  1 ,
# 'Cleaning':  1 ,
# 'Up':  2 ,
# 'Spills':  1 ,
# 'xe2x80x98Cocoxe2x80x99':  1 ,
# 'Mexicoxe2x80x99s':  2 ,
# 'Infatuation':  1 ,
# 'Afterlife':  1 ,
# 'Mexico':  2 ,
# 'spirits':  1 ,
# 'gentle':  1 ,
# 'even':  1 ,
# 'lovable':  1 ,
# 'always':  1 ,
# 'ready':  1 ,
# 'offer':  1 ,
# 'counsel':  1 ,
# 'Pandemics':  1 ,
# 'Tend':  1 ,
# 'Come':  1 ,
# 'Outside':  1 ,
# 'Season':  2 ,
# 'Theater':  3 ,
# 'xe2x80x98Cruel':  2 ,
# 'Intentionsxe2x80x99':  2 ,
# 'Quasi':  1 ,
# 'xe2x80x9990s':  2 ,
# 'Concert':  1 ,
# 'An':  2 ,
# 'Everyman':  1 ,
# 'Just':  1 ,
# 'Ours':  1 ,
# 'Day':  2 ,
# 'Trying':  2 ,
# 'Things':  4 ,
# 'So':  2 ,
# 'Hard':  1 ,
# 'Do':  3 ,
# 'Fly':  1 ,
# 'Fishing':  1 ,
# 'Sees':  1 ,
# 'Women':  1 ,
# 'Source':  1 ,
# 'Growth':  1 ,
# 'Manipulation':  1 ,
# 'Democracy':  1 ,
# 'Online':  1 ,
# 'Battle':  1 ,
# 'SelfPreservation':  1 ,
# 'Putinxe2x80x99s':  1 ,
# 'Reelection':  1 ,
# 'Assured':  1 ,
# 'Let':  1 ,
# 'Succession':  1 ,
# 'Fight':  1 ,
# 'Begin':  1 ,
# 'Whirlwind':  1 ,
# 'Putin':  1 ,
# 'Tour':  1 ,
# 'Highlights':  1 ,
# 'Moscowxe2x80x99s':  1 ,
# 'Reach':  1 ,
# 'Mideast':  1 ,
# 'Campaign':  1 ,
# 'Drive':  1 ,
# 'Slams':  1 ,
# 'Beijingxe2x80x99s':  1 ,
# 'Brightest':  1 ,
# 'Show':  1 ,
# 'Ineffectiveness':  1 ,
# 'Economic':  1 ,
# 'Planxe2x80x99s':  1 ,
# 'Biggest':  1 ,
# 'Cuts':  1 ,
# 'Could':  2 ,
# 'Standards':  1 ,
# '157':  1 ,
# 'Billion':  1 ,
# 'OpEd':  4 ,
# 'Contributor':  2 ,
# 'Unlikely':  1 ,
# 'NailBiter':  1 ,
# 'Races':  1 ,
# 'Finish':  1 ,
# 'Line':  2 ,
# 'It':  3 ,
# 'Happened':  1 ,
# 'Footage':  1 ,
# 'xe2x80x98Attempted':  1 ,
# 'Terrorist':  1 ,
# 'Attackxe2x80x99':  1 ,
# 'Transit':  1 ,
# 'Hub':  1 ,
# 'Shift':  1 ,
# 'xe2x80x98AltRightxe2x80x99':  1 ,
# 'Created':  1 ,
# 'Parallel':  1 ,
# 'Itxe2x80x99s':  2 ,
# 'Unholy':  1 ,
# 'Mess':  1 ,
# 'Bypass':  1 ,
# 'Anxiety':  1 ,
# 'Road':  2 ,
# 'Driverless':  1 ,
# 'Cars':  2 ,
# 'Net':  1 ,
# 'Neutralityxe2x80x99s':  1 ,
# 'Holes':  1 ,
# 'Europe':  1 ,
# 'Offer':  1 ,
# 'Peek':  1 ,
# 'Future':  1 ,
# 'Golden':  8 ,
# 'Globes':  6 ,
# 'xe2x80x98The':  3 ,
# 'Shape':  2 ,
# 'Waterxe2x80x99':  2 ,
# 'xe2x80x98Big':  2 ,
# 'Little':  2 ,
# 'Liesxe2x80x99':  2 ,
# 'Lead':  2 ,
# 'Globe':  2 ,
# 'Nominations':  2 ,
# 'TV':  3 ,
# 'Surprises':  4 ,
# 'Snubs':  4 ,
# '2018':  4 ,
# 'Carpetbagger':  3 ,
# 'Movie':  2 ,
# 'ObamaEra':  1 ,
# 'Four':  1 ,
# 'Fingerprints':  1 ,
# 'Russian':  1 ,
# 'Disinformation':  1 ,
# 'Fake':  1 ,
# 'Fashion':  2 ,
# 'Robots':  1 ,
# 'Take':  3 ,
# 'Childrenxe2x80x99s':  1 ,
# 'Me':  1 ,
# 'Time':  1 ,
# 'Three':  2 ,
# 'Minutes':  1 ,
# 'Minus':  1 ,
# '230':  1 ,
# 'Degrees':  1 ,
# 'Sure':  1 ,
# 'Wexe2x80x99ll':  3 ,
# 'Ho':  3 ,
# 'Office':  1 ,
# 'Parties':  1 ,
# 'Feel':  2 ,
# 'Chill':  1 ,
# 'Movies':  3 ,
# 'Jessica':  1 ,
# 'Chastain':  1 ,
# 'Feared':  1 ,
# 'Speaking':  1 ,
# 'Hurt':  1 ,
# 'Her':  1 ,
# 'Career':  1 ,
# 'Strikes':  1 ,
# 'Near':  1 ,
# 'Disrupting':  1 ,
# 'City':  2 ,
# 'Killing':  1 ,
# 'None':  1 ,
# '2':  1 ,
# 'Others':  1 ,
# 'On':  3 ,
# 'Baseball':  1 ,
# 'Giancarlo':  1 ,
# 'Stanton':  1 ,
# 'xe2x80x98Excited':  1 ,
# 'Better':  1 ,
# 'Togetherxe2x80x99':  1 ,
# 'Yankees':  1 ,
# 'Pro':  1 ,
# 'Basketball':  1 ,
# 'Fix':  1 ,
# 'Lonzo':  1 ,
# 'Ballxe2x80x99s':  1 ,
# 'Look':  1 ,
# 'This':  2 ,
# 'Blueprint':  1 ,
# 'Unexpected':  1 ,
# 'Broadway':  1 ,
# 'Edmonton':  1 ,
# 'High':  1 ,
# 'School':  1 ,
# 'Schemers':  1 ,
# 'Sing':  1 ,
# 'xe2x80x98Jack':  1 ,
# 'Beanstalkxe2x80x99':  1 ,
# 'Treat':  1 ,
# 'Worth':  1 ,
# 'Savoring':  1 ,
# 'Basics':  1 ,
# 'Trilobites':  1 ,
# 'Pacific':  1 ,
# 'Island':  1 ,
# 'Resemble':  1 ,
# 'Ancient':  1 ,
# 'Martian':  1 ,
# 'Volcanoes':  1 ,
# 'Announces':  1 ,
# 'That':  4 ,
# 'Moon':  1 ,
# 'Astronautsxe2x80x99':  1 ,
# 'Next':  1 ,
# 'Obituaries':  2 ,
# 'Reed':  1 ,
# 'Reporter':  1 ,
# 'Covered':  1 ,
# 'Civil':  1 ,
# 'Rights':  1 ,
# 'Era':  1 ,
# '87':  1 ,
# 'Loeb':  1 ,
# 'Editor':  1 ,
# 'Shaped':  1 ,
# 'Money':  1 ,
# 'Fortune':  1 ,
# 'Magazines':  1 ,
# '88':  1 ,
# 'James':  1 ,
# 'Hanley':  1 ,
# 'Negotiator':  1 ,
# 'Mayors':  1 ,
# '69':  1 ,
# 'Walking':  2 ,
# 'Dead':  1 ,
# 'Deadxe2x80x99':  1 ,
# '8':  2 ,
# 'Episode':  1 ,
# 'Sacrificial':  1 ,
# 'Lamb':  1 ,
# 'Nasty':  1 ,
# 'NaftaRelated':  1 ,
# 'Surprise':  1 ,
# 'Soaring':  1 ,
# 'Obesity':  1 ,
# 'Birth':  1 ,
# 'Control':  1 ,
# 'Pills':  2 ,
# 'Protect':  1 ,
# 'Against':  1 ,
# 'Cancer':  1 ,
# 'Too':  1 ,
# 'Prescription':  1 ,
# 'Drugs':  1 ,
# 'Insurance':  1 ,
# 'Than':  1 ,
# 'Without':  1 ,
# 'Smaller':  1 ,
# 'Resorts':  1 ,
# 'Lodges':  1 ,
# 'Lifts':  1 ,
# 'Runs':  1 ,
# 'Getaway':  1 ,
# 'Skiers':  1 ,
# 'Uphill':  1 ,
# 'Way':  1 ,
# 'Books':  4 ,
# 'Adding':  1 ,
# 'Prolific':  1 ,
# 'Poetxe2x80x99s':  1 ,
# 'Charming':  1 ,
# 'Weather':  1 ,
# 'Reports':  1 ,
# 'Nonfiction':  1 ,
# 'Comic':  1 ,
# 'Stripxe2x80x99s':  1 ,
# 'Heyday':  1 ,
# 'xe2x80x98Cartoon':  1 ,
# 'Countyxe2x80x99':  1 ,
# 'Colleges':  1 ,
# 'Want':  2 ,
# 'Applicant':  1 ,
# 'Everything':  1 ,
# '10':  2 ,
# 'Getting':  2 ,
# 'Into':  1 ,
# 'Dream':  1 ,
# 'College':  2 ,
# 'Six':  1 ,
# 'Myths':  1 ,
# 'Choosing':  1 ,
# 'Major':  1 ,
# 'Dishes':  1 ,
# 'Good':  1 ,
# 'Appetite':  1 ,
# 'Pamper':  1 ,
# 'Guests':  1 ,
# 'Gougxc3xa8res':  1 ,
# 'Great':  3 ,
# 'Performers':  3 ,
# 'Yearxe2x80x99s':  1 ,
# 'Actors':  1 ,
# 'Series':  1 ,
# 'Short':  1 ,
# 'Frightening':  1 ,
# 'Films':  1 ,
# 'Fright':  1 ,
# 'Club':  2 ,
# 'Notebook':  1 ,
# 'Few':  1 ,
# 'Favorite':  1 ,
# 'Horror':  1 ,
# 'Renters':  1 ,
# 'Kew':  1 ,
# 'Gardens':  1 ,
# 'Where':  1 ,
# 'Doesnxe2x80x99t':  2 ,
# 'Urban':  1 ,
# 'Whats':  2 ,
# 'Selling':  2 ,
# 'Homes':  3 ,
# 'Around':  2 ,
# 'Ask':  1 ,
# 'Can':  1 ,
# 'Landlord':  1 ,
# 'Anything':  1 ,
# 'Help':  5 ,
# 'Prevent':  2 ,
# 'Package':  1 ,
# 'Training':  2 ,
# 'Care':  1 ,
# 'People':  1 ,
# 'Their':  1 ,
# 'Only':  1 ,
# 'Thing':  1 ,
# 'Seems':  1 ,
# 'Dec':  1 ,
# '18':  1 ,
# 'Live':  1 ,
# 'Event':  1 ,
# 'Podcast':  1 ,
# 'IRL':  1 ,
# 'Hosts':  1 ,
# 'xe2x80x98By':  1 ,
# 'Bookxe2x80x99':  1 ,
# 'Automobiles':  2 ,
# 'RideHailing':  1 ,
# 'War':  1 ,
# 'Being':  2 ,
# 'Waged':  1 ,
# 'Motorbikes':  1 ,
# 'Ford':  1 ,
# 'Build':  2 ,
# 'Electric':  1 ,
# 'Shifting':  1 ,
# 'Its':  2 ,
# 'Chinaxe2x80x99s':  1 ,
# 'AI':  1 ,
# 'Advances':  1 ,
# 'Industry':  1 ,
# 'State':  1 ,
# 'Security':  3 ,
# 'Editorsxe2x80x99':  1 ,
# 'Fantasy':  1 ,
# 'JayZ':  1 ,
# 'Discusses':  1 ,
# 'Rap':  1 ,
# 'Marriage':  1 ,
# 'Black':  1 ,
# 'Man':  1 ,
# 'Clothing':  1 ,
# 'Simplifies':  1 ,
# 'Dressed':  1 ,
# 'Compiled':  1 ,
# 'C':  1 ,
# 'HUGHES':  1 ,
# 'Recent':  1 ,
# 'residential':  1 ,
# 'sales':  1 ,
# 'Sale':  2 ,
# 'Rent':  1 ,
# 'Mortgage':  1 ,
# 'Calculator':  1 ,
# 'Most':  2 ,
# 'Emailed':  1 ,
# 'Viewed':  1 ,
# 'Trending':  1 ,
# 'Recommended':  1 ,
# 'Home':  2 ,
# 'Page':  1 ,
# 'Index':  2 ,
# 'Todays':  3 ,
# 'Corrections':  1 ,
# 'Columnists':  1 ,
# 'Editorials':  1 ,
# 'Contributors':  1 ,
# 'Letters':  1 ,
# 'Art':  1 ,
# 'Design':  1 ,
# 'Dance':  1 ,
# 'NYC':  3 ,
# 'Events':  3 ,
# 'Weddings':  1 ,
# 'Celebrations':  1 ,
# 'Listings':  1 ,
# 'Reader':  1 ,
# 'Classifieds':  1 ,
# 'Tools':  1 ,
# 'Services':  2 ,
# 'Photography':  1 ,
# 'NYT':  1 ,
# 'Store':  1 ,
# 'Journeys':  1 ,
# 'Manage':  2 ,
# 'My':  1 ,
# 'Account':  1 ,
# 'NYTCo':  1 ,
# 'Delivery':  1 ,
# 'Digital':  1 ,
# 'Email':  3 ,
# 'Newsletters':  1 ,
# 'Alerts':  1 ,
# 'Group':  1 ,
# 'Rate':  1 ,
# 'Applications':  1 ,
# 'Replica':  1 ,
# 'Information':  2 ,
# 'copy':  2 ,
# 'Company':  2 ,
# 'Contact':  2 ,
# 'Us':  2 ,
# 'Advertise':  1 ,
# 'Ad':  1 ,
# 'Choices':  1 ,
# 'Privacy':  2 ,
# 'Terms':  3 ,
# 'Service':  1 ,
# 'Map':  1 ,
# 'Feedback':  1 ,
# 'View':  1 ,
# 'Version':  1 ,
# 'bnnnnnn':  1 ,
# 'nnnn':  4 ,
# 'world39s':  1 ,
# 'leading':  1 ,
# 'software':  4 ,
# 'development':  3 ,
# 'platform':  2 ,
# 'xc2xb7':  1 ,
# 'GitHub':  24 ,
# 'nnnnnn':  1 ,
# 'Featuresn':  1 ,
# 'Businessn':  2 ,
# 'Exploren':  1 ,
# 'Marketplacen':  1 ,
# 'Pricingn':  1 ,
# 'dashboard':  1 ,
# 'Sign':  8 ,
# 'Built':  1 ,
# 'developers':  4 ,
# 'inspired':  1 ,
# 'way':  3 ,
# 'source':  2 ,
# 'host':  2 ,
# 'review':  3 ,
# 'code':  6 ,
# 'projects':  2 ,
# 'build':  4 ,
# 'alongside':  3 ,
# 'millions':  2 ,
# 'othernbspdevelopersn':  1 ,
# 'Username':  2 ,
# 'Password':  2 ,
# 'Use':  1 ,
# 'least':  1 ,
# 'one':  3 ,
# 'letter':  1 ,
# 'numeral':  1 ,
# 'seven':  1 ,
# 'characters':  1 ,
# 'clicking':  2 ,
# 'agree':  2 ,
# 'ourn':  2 ,
# 'terms':  2 ,
# 'service':  2 ,
# 'andn':  2 ,
# 'privacy':  2 ,
# 'occasionally':  2 ,
# 'send':  2 ,
# 'account':  3 ,
# 'related':  2 ,
# 'emails':  2 ,
# 'teamsn':  1 ,
# 'better':  2 ,
# 'togethern':  1 ,
# 'brings':  1 ,
# 'teams':  3 ,
# 'together':  3 ,
# 'problems':  2 ,
# 'ideas':  1 ,
# 'forward':  1 ,
# 'learn':  1 ,
# 'each':  1 ,
# 'along':  1 ,
# 'wayn':  1 ,
# 'Write':  1 ,
# 'Collaboration':  1 ,
# 'makes':  1 ,
# 'perfect':  1 ,
# 'conversations':  1 ,
# 'reviews':  1 ,
# 'happen':  2 ,
# 'Pull':  1 ,
# 'Requests':  1 ,
# 'share':  2 ,
# 'weight':  1 ,
# 'improve':  1 ,
# 'chaos':  1 ,
# 'breath':  1 ,
# 'project':  2 ,
# 'management':  3 ,
# 'happens':  1 ,
# 'Issues':  1 ,
# 'Projects':  1 ,
# 'right':  2 ,
# 'do':  1 ,
# 'mention':  1 ,
# 'teammate':  1 ,
# 'involved':  1 ,
# 'Find':  2 ,
# 'tools':  3 ,
# 'Browse':  2 ,
# 'buy':  1 ,
# 'apps':  2 ,
# 'Marketplace':  2 ,
# 'like':  1 ,
# 'discover':  2 ,
# 'new':  3 ,
# 'favoritesxe2x80x94then':  1 ,
# 'using':  3 ,
# 'minutes':  1 ,
# 'integrations':  2 ,
# 'administrationn':  1 ,
# 'Boxes':  1 ,
# 'Checkn':  1 ,
# 'worry':  1 ,
# 'administrative':  1 ,
# 'security':  2 ,
# 'donxe2x80x99t':  1 ,
# 'flexible':  1 ,
# 'hosting':  3 ,
# 'authentication':  2 ,
# 'options':  1 ,
# 'meet':  1 ,
# 'teamxe2x80x99s':  1 ,
# 'requirementsn':  1 ,
# 'Code':  3 ,
# 'before':  1 ,
# 'Protected':  1 ,
# 'branches':  1 ,
# 'signed':  3 ,
# 'commits':  1 ,
# 'required':  1 ,
# 'status':  1 ,
# 'checks':  1 ,
# 'maintain':  2 ,
# 'high':  1 ,
# 'standard':  1 ,
# 'coden':  1 ,
# 'Access':  1 ,
# 'controlled':  1 ,
# 'Encourage':  1 ,
# 'while':  1 ,
# 'limiting':  1 ,
# 'access':  1 ,
# 'granular':  1 ,
# 'permissions':  1 ,
# 'SAMLSSO':  1 ,
# 'LDAPn':  1 ,
# '1clrcodehosting':  1 ,
# 'Hosted':  1 ,
# 'where':  1 ,
# 'Securely':  1 ,
# 'reliably':  1 ,
# 'GitHubcom':  1 ,
# 'Or':  1 ,
# 'deploy':  1 ,
# 'Enterprise':  1 ,
# 'own':  1 ,
# 'servers':  1 ,
# 'private':  1 ,
# 'cloud':  1 ,
# 'Amazon':  1 ,
# 'Web':  1 ,
# 'Azure':  1 ,
# 'Cloud':  1 ,
# 'Platform':  2 ,
# 'Compare':  1 ,
# 'plans':  1 ,
# 'Integrationsn':  1 ,
# 'GitHubn':  2 ,
# 'Customize':  1 ,
# 'process':  2 ,
# 'intuitive':  1 ,
# 'API':  1 ,
# 'Integrate':  1 ,
# 'already':  2 ,
# 'use':  4 ,
# 'favorites':  1 ,
# 'create':  2 ,
# 'happier':  1 ,
# 'efficient':  1 ,
# 'workingn':  1 ,
# 'Sometimes':  1 ,
# 'therexe2x80x99s':  2 ,
# 'tool':  1 ,
# 'try':  1 ,
# 'something':  1 ,
# 'newn':  1 ,
# 'Communityn':  1 ,
# 'Welcome':  1 ,
# 'home':  2 ,
# 'developersn':  1 ,
# 'worldxe2x80x99s':  1 ,
# 'largest':  2 ,
# 'community':  1 ,
# 'theirnbspprojectsn':  1 ,
# 'Ariya':  1 ,
# 'Hidayat':  1 ,
# 'PhantomJS':  1 ,
# 'maintainern':  5 ,
# 'Russell':  1 ,
# 'KeithMagee':  1 ,
# 'PyBee':  1 ,
# 'MailChimp':  1 ,
# 'Marketing':  1 ,
# 'customern':  2 ,
# 'Kris':  1 ,
# 'Nova':  1 ,
# 'Kuberneteskops':  1 ,
# 'Evan':  1 ,
# 'Vue':  1 ,
# 'Mapbox':  1 ,
# 'Software':  1 ,
# 'Jess':  1 ,
# 'Frazelle':  1 ,
# 'Kubernetes':  1 ,
# 'previously':  1 ,
# 'Docker':  1 ,
# 'whether':  1 ,
# 'youxe2x80x99re':  1 ,
# 'making':  1 ,
# 'commit':  1 ,
# 'sending':  1 ,
# 'Rover':  1 ,
# 'Mars':  1 ,
# 'room':  1 ,
# 'here':  1 ,
# 'toon':  1 ,
# '73M':  1 ,
# 'repositories':  1 ,
# 'worldwide':  3 ,
# 'GitHubxe2x80x99s':  1 ,
# 'users':  1 ,
# 'influential':  1 ,
# 'technologies':  1 ,
# 'worlds':  1 ,
# 'sourcenbspcommunity':  1 ,
# '26M':  1 ,
# 'Developers':  2 ,
# 'personal':  1 ,
# 'experimenting':  1 ,
# 'programming':  1 ,
# 'languages':  1 ,
# 'lifexe2x80x99s':  1 ,
# '117K':  1 ,
# 'Businesses':  1 ,
# 'sizes':  1 ,
# 'securely':  1 ,
# 'million':  1 ,
# 'started':  1 ,
# 'free':  1 ,
# 'mdash':  1 ,
# 'join':  1 ,
# 'amazing':  1 ,
# 'thingsn':  1 ,
# '2017n':  1 ,
# 'Features':  1 ,
# 'Project':  1 ,
# 'Community':  3 ,
# 'Documentation':  1 ,
# 'Atom':  1 ,
# 'Electron':  1 ,
# 'Desktop':  1 ,
# 'Personal':  1 ,
# 'Open':  1 ,
# 'Customers':  1 ,
# 'Partners':  1 ,
# 'Sponsorships':  1 ,
# 'Blog':  1 ,
# 'Careers':  1 ,
# 'Press':  1 ,
# 'Shop':  1 ,
# 'Resources':  1 ,
# 'Forum':  1 ,
# 'Status':  1 ,
# 'nnnnn':  1 ,
# 'cant':  1 ,
# 'perform':  1 ,
# 'action':  1 ,
# 'timen':  1 ,
# 'another':  2 ,
# 'tab':  2 ,
# 'window':  2 ,
# 'Reload':  2 ,
# 'refresh':  2 ,
# 'session':  2 ,
# 'out':  1 ,
# }
# <Maximum Frequency Word List>
#  - Frequency :  2935
# n
#
# <Maximum Frequency Word List>
#  - Frequency :  2392
# n

# %% [markdown]
# #### [설명]
#
# - 대부분의 소스 코드는 이전 과제에서 참조하였으나, 문제가 요구한 대로 파일 입출력에 대한 기능을 전부 지워야 했고, 본 문제에 알맞게 함수를 개편해야 했다.
# - 생성자에서는 가변인수로 받은 url 주소값들을 리스트로 변환하여 저장한다.
# - 따라서 url을 추가하고 삭제하는 멤버 메소드는 리스트 내장 함수를 활용하여 기능을 구현하였다.
# - 사전을 구성하는 부분은 3번째 과제 마지막 문제 거의 그대로 사용하게 되었다. 약간 달라진 점이 있다면 url 단어 파싱 기능을 메소드의 형태로 구현하되, url을 입력받으면 사전을 반환하도록 만들었다. 이러한 구조는 이전 과제의 파일 입출력을 위해 재구성한 단어 파싱 함수와 거의 유사하다고 할 수 있으나, 사전을 반환하느냐, 아님 파일을 생성하느냐라는 점에서 차이점이 있다.
# - 사전에서 최대 빈도를 찾는 기능은 이전 과제 소스 코드와 거의 동일하다. 흔한 순차 탐색 최대값 알고리즘을 이용하여 최대 빈도값을 알아내는데, 탐색을 하면서 최대 빈도 값과 같은 단어가 존재하면 최대 빈도수를 지닌 단어들을 저장하는 리스트에 이를 추가한다. 더 큰 빈도수의 단어가 발견되면 이전의 단어 리스트 대신에 새로운 단어 리스트로 바꾼다.
#  - 사전을 print로 표준 출력하고자 하였으나, 한글이 깨지는 현상이 발생하여 따로 사전 객체의 내용을 출력하는 함수를 만들었다.
#
#  - - amazon 사이트는 HTTP 503 error 발생

# %% [markdown]
# ## [8번 문제], 9번문제 같이
#
# 위 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.
#
# - 리스트 내의 각 원소는 단어와 빈도를 쌍으로 지니는 튜플이다.
# - getWordFrequence() 메소드에 reverse 라는 인자를 만들고 true 또는 false를 인자로 받을 수 있도록 한다.
#
#   - reverse 인자의 디폴트 값은 false 이며, 기본적으로 내림차순으로 정렬한다.
#   - reverse 인자에 true를 넣으면 오름차순으로 정렬한다.
#
# > w4 = OrderedWebWordsFrequency('http://www.times.com', 'https://www.amazon.com', 'https://github.com')
#
# > w4.getWordsFrequency()
#
# [('site', 12), ('science', 11), ('hello', 8), ('world', 2), ('program', 1), ('python', 1)]
#
# > w4.getWordsFrequency(reverse=true)
#
# [('program', 1), ('python', 1), ('world', 2), ('hello', 8), ('science', 11), ('site', 12)]

# %% [markdown]
# ### [9번 문제]
#
# [9번 문제]
# 다음과 같은 코딩이 가능하도록 OrderedWebWordsFrequency 안에 반복자와 관련된 메소드를 추가하시오.
#
# >for i in w4:
#
# > print(i)
#
# ('site, 12)
# ('science', 11)
# ('hello', 8)
# ('world', 2)
# ('program', 1)
# ('python', 1)

# %%
#!/usr/local/bin/python
# coding: utf-8
import sys, os, urllib, string, operator
from urllib.request import urlopen

def dictListCmp(dl1, dl2):
    return cmp(dl2[1], dl1[1])

def printDictForKorKey(d):
    if len(d) == 0:
        print('{}')
    else:
        print('{',)
        for key, value in d.items():
            print('\'' + key + '\': ', value, ',',)
        print('}')

def printDictListForKorKey(dl):
    if len(dl) == 0:
        print('[]')
    else:
        print('[',)
        for tempDl in dl:
            print('(\'' + tempDl[0] + '\',' + str(tempDl[1]) +')',)
        print(']')

# Url을 파싱하여 단어 및 단어 개수를 사전 형태로 반환하는 함수다.
def parsingUrl(url):
    #s = urllib.urlopen(url).read()
    #s = urlopen(url).read()
    s = str(urlopen(url).read())
    
#    print(type(s)) #debug
#    print(str(s))  #debug
    
    
    n = 0
    pivot = 0
    while(n < len(s)):
        if(s[n] == "<" and s[n + 1 : n + 7].lower() == "script"):
            pivot = n
            while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 8].lower() != "script"):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+9:]

        elif(s[n] == "<" and s[n + 1 : n + 6].lower() == "style"):
            pivot = n
            while(s[pivot] != "<" or s[pivot + 1] != "/" or s[pivot + 2 : pivot + 7].lower() != "style"):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+8:]

        elif(s[n] == '<'):
            pivot = n
            while(s[pivot] != '>'):
                pivot += 1
            s = s[0:n] + ' ' + s[pivot+1:]
        elif(s[n] == '\n' or s[n] == '\t'):
            s = s[0:n] + ' ' + s[n+1:]
        elif(s[n] in string.punctuation):
            s = s[0:n] + s[n+1:]
        else:
            n += 1

    s2 = s.split()
    s3 = ' '.join(s2)
    n = 0
    D = {}
    i = 0
    
#    while(n < len(s2)):
#        while(i < len(stopword)):
#            if(s2[n] == stopword[i]):
#                s2.remove(s2[n])
#            i = i+1
#        n = n+1
    while(n < len(s2)):
        if(s2[n] in D.keys()):
            D[s2[n]] += 1
        else:
            D[s2[n]] = 1
        n += 1

    return D


# 웹사이트 상의 단어 빈도에 대한 정보를 다루는 클래스다.
class WebWordsFrequency:

    # 생성자
    def __init__(self, *urls):
        self.urlList = list(urls)

    # Url 추가
    def addUrl(self, strUrl):
        self.urlList.append(strUrl)

    # Url 삭제
    def removeUrl(self, strUrl):
        self.urlList.remove(strUrl)

    # Url 목록 출력
    def listUrls(self):
        for e in self.urlList:
            print(e)

    # 저장된 웹사이트 url에 기반한 단어 빈도 사전 출력
    def getWordsFrequency(self):
        totalDict = {}
        
        for urls in self.urlList:
            D = parsingUrl(urls)
            keys = totalDict.keys()
            for key, value in D.items():
                if(key in keys):
                    totalDict[key] += value
                else:
                    totalDict[key] = value
        return totalDict

    # 최다 빈도 출현 단어 출력
    def getMaxFrequencyWords(self):
        if len(self.urlList) == 0:
            return None
        else:
            maxValues = 0
            maxKeys = []
            maxUrls = ' '
            
            totalDict = {}

            for urls in self.urlList:
                D = parsingUrl(urls)
                keys = totalDict.keys()
                for key, value in D.items():
                    if(key in keys):
                        totalDict[key] += value
                    else:
                        totalDict[key] = value
        
            for key, value in totalDict.items():
                if(maxValues < value):
                    maxValues = value
                    maxKeys = [key]
                elif(maxValues == value):
                    maxKeys.append(key)
            
            print("<Maximum Frequency Word List>")
            print(" - Frequency : ", maxValues)
            for k in maxKeys:
                print(k)
            print()

class OrderedWebWordsFrequency(WebWordsFrequency):
    def getWordsFrequency(self):
        totalDict = {}
        totalDictList = []

        for urls in self.urlList:
            D = parsingUrl(urls)
            keys = totalDict.keys()
            for key, value in D.items():
                if(key in keys):
                    totalDict[key] += value
                else:
                    totalDict[key] = value

#        print(type(dictListCmp))        #debug
#        print(dictListCmp)              #debug
#        print(totalDict.items())        #debug
        print(type(totalDict))
        
        dc = totalDict
    
        dc_sort = sorted(dc.items(),key = operator.itemgetter(1),reverse = True)
        dc_sort = dict(dc_sort)
        
        for key, value in dc_sort.items():
#            print(key, value)           #debug
            totalDictList.append((key, value))
#            totalDictList.sort(dictListCmp)

        return totalDictList
        

if __name__ == "__main__":
    w4 = OrderedWebWordsFrequency('http://www.times.com', 'https://github.com')
    printDictListForKorKey(w4.getWordsFrequency())
# Out:
# <class 'dict'>
# [
# ('n',2940)
# ('nn',475)
# ('the',82)
# ('to',78)
# ('of',61)
# ('and',60)
# ('a',60)
# ('rn',50)
# ('for',49)
# ('The',45)
# ('in',44)
# ('raquo',33)
# ('rnrn',27)
# ('New',26)
# ('GitHub',24)
# ('By',23)
# ('you',19)
# ('your',18)
# ('York',16)
# ('Times',16)
# ('on',15)
# ('nt',15)
# ('nnn',12)
# ('at',12)
# ('or',11)
# ('From',11)
# ('that',11)
# ('work',11)
# ('Site',10)
# ('Opinion',10)
# ('AM',10)
# ('ET',10)
# ('by',10)
# ('with',10)
# ('With',9)
# ('Is',9)
# ('A',9)
# ('about',9)
# ('US',8)
# ('up',8)
# ('nttt',8)
# ('Golden',8)
# ('Sign',8)
# ('News',7)
# ('Search',7)
# ('Navigation',7)
# ('Health',7)
# ('Magazine',7)
# ('How',7)
# ('who',7)
# ('an',7)
# ('About',7)
# ('More',7)
# ('Sexual',7)
# ('Education',7)
# ('is',7)
# ('help',7)
# ('All',7)
# ('World',6)
# ('In',6)
# ('2017',6)
# ('Video',6)
# ('Business',6)
# ('Arts',6)
# ('What',6)
# ('Alabama',6)
# ('Roy',6)
# ('nbspComments',6)
# ('Why',6)
# ('their',6)
# ('Misconduct',6)
# ('have',6)
# ('nntnt',6)
# ('Over',6)
# ('Learn',6)
# ('rnrnrn',6)
# ('You',6)
# ('Guide',6)
# ('Our',6)
# ('ntttt',6)
# ('Globes',6)
# ('code',6)
# ('Subscribe',5)
# ('Sports',5)
# ('Real',5)
# ('Estate',5)
# ('as',5)
# ('Trump',5)
# ('No',5)
# ('Will',5)
# ('Bombing',5)
# ('they',5)
# ('more',5)
# ('Your',5)
# ('but',5)
# ('It',5)
# ('Dies',5)
# ('from',5)
# ('Best',5)
# ('Subscriptions',5)
# ('Work',5)
# ('Review',5)
# ('Help',5)
# ('maintainern',5)
# ('xc2xbb',4)
# ('Sections',4)
# ('Politics',4)
# ('Style',4)
# ('Food',4)
# ('Travel',4)
# ('T',4)
# ('Go',4)
# ('Moore',4)
# ('nntt',4)
# ('ntnt',4)
# ('Trumpxe2x80x99s',4)
# ('his',4)
# ('Cases',4)
# ('them',4)
# ('Amid',4)
# ('Bill',4)
# ('need',4)
# ('We',4)
# ('Daily',4)
# ('Living',4)
# ('Holiday',4)
# ('than',4)
# ('policy',4)
# ('can',4)
# ('he',4)
# ('Sold',4)
# ('has',4)
# ('new',4)
# ('t',4)
# ('Crossword',4)
# ('Things',4)
# ('Do',4)
# ('OpEd',4)
# ('Surprises',4)
# ('Snubs',4)
# ('2018',4)
# ('Books',4)
# ('nnnn',4)
# ('worldxe2x80x99s',1)
# ('community',1)
# ('theirnbspprojectsn',1)
# ('Ariya',1)
# ('Hidayat',1)
# ('PhantomJS',1)
# ('Russell',1)
# ('KeithMagee',1)
# ('PyBee',1)
# ('MailChimp',1)
# ('Marketing',1)
# ('Kris',1)
# ('Nova',1)
# ('Kuberneteskops',1)
# ('Evan',1)
# ('Vue',1)
# ('Mapbox',1)
# ('Software',1)
# ('Jess',1)
# ('Frazelle',1)
# ('Kubernetes',1)
# ('previously',1)
# ('Docker',1)
# ('whether',1)
# ('youxe2x80x99re',1)
# ('making',1)
# ('commit',1)
# ('sending',1)
# ('Rover',1)
# ('Mars',1)
# ('room',1)
# ('here',1)
# ('toon',1)
# ('73M',1)
# ('repositories',1)
# ('GitHubxe2x80x99s',1)
# ('users',1)
# ('influential',1)
# ('technologies',1)
# ('worlds',1)
# ('sourcenbspcommunity',1)
# ('26M',1)
# ('personal',1)
# ('experimenting',1)
# ('programming',1)
# ('languages',1)
# ('lifexe2x80x99s',1)
# ('117K',1)
# ('Businesses',1)
# ('sizes',1)
# ('support',1)
# ('securely',1)
# ('million',1)
# ('started',1)
# ('free',1)
# ('mdash',1)
# ('join',1)
# ('amazing',1)
# ('thingsn',1)
# ('2017n',1)
# ('Features',1)
# ('Project',1)
# ('Documentation',1)
# ('Atom',1)
# ('Electron',1)
# ('Desktop',1)
# ('Personal',1)
# ('Open',1)
# ('Customers',1)
# ('Partners',1)
# ('Sponsorships',1)
# ('Blog',1)
# ('Careers',1)
# ('Press',1)
# ('Shop',1)
# ('Resources',1)
# ('Forum',1)
# ('Status',1)
# ('nnnnn',1)
# ('cant',1)
# ('perform',1)
# ('action',1)
# ('timen',1)
# ('out',1)
# ]

# %% [markdown]
# #### [설명]
#
# 예전 과제를 통해 구현해본 기능이라 어렵지 않게 문제를 해결할 수 있었다.
# 여러 url 주소에서 가져온 단어 사전을 하나로 합친 뒤, 튜플을 원소로 갖는 리스트로 변환하였다.
# 비교 함수를 따로 만들어 value 값을 기준으로 단어 빈도수 비교가 이루어지도록 하였다.
# 이전 문제와 마찬가지로 print로는 기존 사전 객체의 한글 출력 문제가 있어 따로 출력 함수를 만들었다.
#
# - amazon 사이트는 HTTP 503 error 발생

# %% [markdown]
# #### [소감]
#
# 파이썬을 통해 프로그래밍에 대한 패러다임이 많이 바뀌게 되었다. 처음부터 C, C++에 익숙해져 있었기 때문에 객체보다는 절차적, 함수적 프로그래밍에 익숙해져 있었다. 하지만 파이썬은 철저하게 객체지향적이기 때문에 프로그래밍을 하면서 머리속으로 그리는 알고리즘이나 프로그램의 구성도, 생각의 흐름이나 방식이 절차 지향에서 객체 지향으로 넘어올 수 있었다. 객체라는 개념이 포인터 다음으로 이해하기 어려웠기 때문에 개인적으로 해결해야 할 과제로서 남아 있었는데, 이 수업에서 이를 해결할 수 있어서 정말 감회가 깊고 여운이 남는다. 비록 파이썬의 방대한 내용을 소화하기는 어려웠고, 실제로 소화를 다 하지 못하고 끝마치지만 개인적으로 큰 배움을 얻을 수 있어서 기쁘다.
